# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import TensorDataset, DataLoader
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch.nn.functional as F
import math
import time
from sklearn.model_selection import train_test_split
import random
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
# Load the image data
x_train_images = np.load('x_train_wr.npy')
x_test_images = np.load('x_test_wr.npy')
y_train_images = np.load('y_train.npy')

# %%
y_train_images = pd.read('y_train.csv')
y_train_images = y_train_images.to_numpy()

# %%
# Print shapes and dimensions of loaded image data
print("Shape of x_train_image_tensor:", x_train_images.shape)
print("Shape of y_train_image_tensor:", y_train_images.shape)
print("Shape of x_test_image_tensor:", x_test_images.shape)
# Out:
# Shape of x_train_image_tensor: (60000, 784)
# Shape of y_train_image_tensor: (60000,)
# Shape of x_test_image_tensor: (10000, 28, 28)

# %%
# Now let us split the data (x_train_image_tensor and y_train_image_tensor) into training and validation sets in the ratio 80% - 20%

# %%
# Reshape x_train_image_tensor from (60000, 784) to (60000, 28, 28)
x_train_images = x_train_images.reshape(-1, 28, 28)


x_train_image, x_valid_image, y_train_image, y_valid_image = train_test_split(x_train_images, y_train_images, test_size=0.2, random_state=42)

# Print the shapes of the split datasets
print("Shape of x_train:", x_train_image.shape)
print("Shape of y_train:", y_train_image.shape)
print("Shape of x_valid:", x_valid_image.shape)
print("Shape of y_valid:", y_valid_image.shape)

print("Shape of x_test:", x_test_images.shape)
# Out:
# Shape of x_train: (48000, 28, 28)
# Shape of y_train: (48000,)
# Shape of x_valid: (12000, 28, 28)
# Shape of y_valid: (12000,)
# Shape of x_test: (10000, 28, 28)

# %%
# Convert numpy arrays to PyTorch tensors
x_train_image_tensor = torch.tensor(x_train_image, dtype=torch.float32).clone().detach()
y_train_image_tensor = torch.tensor(y_train_image, dtype=torch.float32).clone().detach()
x_valid_image_tensor = torch.tensor(x_valid_image, dtype=torch.float32).clone().detach()
y_valid_image_tensor = torch.tensor(y_valid_image, dtype=torch.float32).clone().detach()
x_test_image_tensor = torch.tensor(x_test_images, dtype=torch.float32).clone().detach()

# %%
# Create DataLoader for image data
batch_size = 64
train_dataset_images = TensorDataset(x_train_image_tensor, y_train_image_tensor)
valid_dataset_images = TensorDataset(x_valid_image_tensor, y_valid_image_tensor)
test_dataset_images = TensorDataset(x_test_image_tensor)

train_loader_images = DataLoader(train_dataset_images, batch_size=batch_size, shuffle=False)
valid_loader_images = DataLoader(valid_dataset_images, batch_size=batch_size, shuffle=False)
test_loader_images = DataLoader(test_dataset_images, batch_size=batch_size, shuffle=False)

# %%
# Plot 5 images from the first batch of training data
fig, axes = plt.subplots(1, 5, figsize=(15, 3))
for i, (image, label) in enumerate(train_loader_images):
    if i == 0:
        for j in range(5):
            axes[j].imshow(image[j].squeeze(), cmap='gray')
            axes[j].set_title(f"Label: {label[j]}")
            axes[j].axis('off')
        break
plt.show()

# %%
# Plot 5 images from the first batch of validation data
fig, axes = plt.subplots(1, 5, figsize=(15, 3))
for i, (image, label) in enumerate(valid_loader_images):
    if i == 0:
        for j in range(5):
            axes[j].imshow(image[j].squeeze(), cmap='gray')
            axes[j].set_title(f"Label: {label[j]}")
            axes[j].axis('off')
        break
plt.show()

# %%
# Plot 5 images from the first batch of test data
fig, axes = plt.subplots(1, 5, figsize=(15, 3))
for images, in test_loader_images:
    for i in range(5):
        axes[i].imshow(images[i].squeeze(), cmap='gray')
        axes[i].axis('off')
    break  
plt.show()

# %%
# the values for each image pix vlaue is between 0 and 1

# %%
# Now importing and transforming the audio data

# %%
# Load the data
x_train_audio = np.load('x_train_sp.npy')
x_test_audio = np.load('x_test_sp.npy')

# %%
# split into training and vlaidation datasets

x_train_audio = x_train_audio.reshape(-1, 507)

# Split the data into training and validation sets 
x_train_audio, x_valid_audio, y_train_audio, y_valid_audio = train_test_split(x_train_audio, y_train_images, test_size=0.2, random_state=42)

# Print the shapes of the split datasets
print("Shape of x_train:", x_train_audio.shape)
print("Shape of y_train:", y_train_audio.shape)
print("Shape of x_valid:", x_valid_audio.shape)
print("Shape of y_valid:", y_valid_audio.shape)

print("Shape of x_test:", x_test_audio.shape)
# Out:
# Shape of x_train: (48000, 507)
# Shape of y_train: (48000,)
# Shape of x_valid: (12000, 507)
# Shape of y_valid: (12000,)
# Shape of x_test: (10000, 507)

# %%
# Convert data to PyTorch tensors
x_train_audio_tensor = torch.tensor(x_train_audio, dtype=torch.float32)
y_train_audio_tensor = torch.tensor(y_train_audio, dtype=torch.float32)
x_valid_audio_tensor = torch.tensor(x_valid_audio, dtype=torch.float32)
y_valid_audio_tensor = torch.tensor(y_valid_audio, dtype=torch.float32)

x_test_audio_tensor = torch.tensor(x_test_audio, dtype=torch.float32)

# %%
# Create DataLoader for image data
batch_size = 64
train_dataset_audios = TensorDataset(x_train_audio_tensor, y_train_audio_tensor)
valid_dataset_audios = TensorDataset(x_valid_audio_tensor, y_valid_audio_tensor)
test_dataset_audios = TensorDataset(x_test_audio_tensor)

train_loader_audios = DataLoader(train_dataset_audios, batch_size=batch_size, shuffle=False)
valid_loader_audios = DataLoader(valid_dataset_audios, batch_size=batch_size, shuffle=False)
test_loader_audios = DataLoader(test_dataset_audios, batch_size=batch_size, shuffle=False)

# %%
for batch_idx, (x_batch, y_batch) in enumerate(train_loader_audios):
    # Plot up to 5 samples from the batch
    for i in range(min(5, len(x_batch))):
        plt.figure(figsize=(10, 3))
        plt.plot(x_batch[i].numpy())
        plt.title(f'Training Sample {i+1} from Batch {batch_idx+1}, Label: {y_batch[i]}')
        plt.xlabel('Time')
        plt.ylabel('Amplitude')
        plt.show()
    break

# %%
for batch_idx, (x_batch, y_batch) in enumerate(valid_loader_audios):
    # Plot up to 5 samples from the batch
    for i in range(min(5, len(x_batch))):
        plt.figure(figsize=(10, 3))
        plt.plot(x_batch[i].numpy())
        plt.title(f'Training Sample {i+1} from Batch {batch_idx+1}, Label: {y_batch[i]}')
        plt.xlabel('Time')
        plt.ylabel('Amplitude')
        plt.show()
    break

# %%
# print("Number of batches in test_loader_audios:", len(test_loader_audios))
# for batch_idx, (x_batch,) in enumerate(test_loader_audios):
#     print(f"Batch {batch_idx+1}:")
#     print("Shape of x_batch:", x_batch.shape)

# %%
# Iterate through the test loader
for batch_idx, (x_batch,) in enumerate(test_loader_audios):
   
    for i in range(min(5, len(x_batch))):
        plt.figure(figsize=(10, 3))
        plt.plot(x_batch[i].numpy())
        plt.title(f'Training Sample {i+1} from Batch {batch_idx+1}')
        plt.xlabel('Time')
        plt.ylabel('Amplitude')
        plt.show()
    break  # Break after plotting the first batch

# %%
# now we see that all train, validation and test datalaoders are ready - for both images and audio
# we also plot 5 samples from each of these to see if all data is distributed as expected

# %%
# CNN for image data
# lets first create a model - check with the validation data- get accuracy
# once this is done and I get a good accuracy- i will then keep only the embeddings 
# further i can use the embeddings for fusion with corresponding audio embeddings

# %%
# declaring a CNN model with filter size, batch normalization layer selections and activation function as hyper-parameters
# setting all layer parameters and # neurons
# calculating the input size needed for the linear layer based on the continuous CNN and pooling layers
  # eg. a 2x2 pooling layer will reduce the dimension to half for l as well as w and so on
# similarly then checking which layers are given for norm- i do batch normalizations
# In forward we set the layer sequencing

class CNNModel(nn.Module):
    def __init__(self, filter_size=3, batchNorm=["l1", "l2", "l3", "l4"], actFun="relu"):
        super().__init__()
        self.batchNorm = batchNorm
        self.activation_function = actFun
        self.StrideSize = 1
        self.out1 = 6
        self.out2 = 12
        self.out3 = 24
        self.out4 = 48
        self.dim = 28
        self.c1, self.c2 = 2, 2

        size_after_conv_layersc1 = self.dim - ((filter_size - self.StrideSize) * self.c1)
        size_after_pool1 = math.ceil(size_after_conv_layersc1 / 2)
        size_after_conv_layersc2 = size_after_pool1 - ((filter_size - self.StrideSize) * self.c2)
        self.size_after_pool2 = int(math.ceil(size_after_conv_layersc2 / 2))

        self.conv1 = nn.Conv2d(1, self.out1, filter_size, self.StrideSize)
        self.conv2 = nn.Conv2d(self.out1, self.out2, filter_size, self.StrideSize)
        self.conv3 = nn.Conv2d(self.out2, self.out3, filter_size, self.StrideSize)
        self.conv4 = nn.Conv2d(self.out3, self.out4, filter_size, self.StrideSize)

        self.fc1 = nn.Linear(48 * self.size_after_pool2 * self.size_after_pool2, 120)  # Adjusted input size here
        self.fc2 = nn.Linear(120, 64)
        self.fc3 = nn.Linear(64, 10)

        if "l1" in self.batchNorm:
            self.batch_norm1 = nn.BatchNorm2d(6)
        if "l2" in self.batchNorm:
            self.batch_norm2 = nn.BatchNorm2d(12)
        if "l3" in self.batchNorm:
            self.batch_norm3 = nn.BatchNorm2d(24)
        if "l4" in self.batchNorm:
            self.batch_norm4 = nn.BatchNorm2d(48)

        self.dropout = nn.Dropout(0.05)

    def forward(self, x):
        if "l1" in self.batchNorm:
            x = self.batch_norm1(getattr(F, self.activation_function)(self.conv1(x)))
        else:
            x = getattr(F, self.activation_function)(self.conv1(x))
        x = getattr(F, self.activation_function)(self.conv2(x))
        if "l2" in self.batchNorm:
            x = self.batch_norm2(x)
        x = F.max_pool2d(x, 2, 2)

        if "l3" in self.batchNorm:
            x = self.batch_norm3(getattr(F, self.activation_function)(self.conv3(x)))
        else:
            x = getattr(F, self.activation_function)(self.conv3(x))
        x = getattr(F, self.activation_function)(self.conv4(x))
        if "l4" in self.batchNorm:
            x = self.batch_norm4(x)
        x = F.max_pool2d(x, 2, 2)

        x = x.view(-1, 48 * self.size_after_pool2 * self.size_after_pool2)  # Adjusted view size here

        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = F.relu(self.fc2(x))
        x1 = self.dropout(x)
        x = F.relu(self.fc3(x1))
        log_softmax_output = F.log_softmax(x, dim=1)

        return x, x1

# %%
normLayers = ["l1","l2","l3","l4","l5"]
actFun = "tanh"
filter_size = 3
model_name = f"CNNImagemodel_{'_'.join(normLayers)}_{actFun}_{filter_size}"
model_name
# Out:
# 'CNNImagemodel_l1_l2_l3_l4_l5_tanh_3'

# %%
start_time = time.time()

epochs = 10
train_losses, test_losses = [], []
train_correct, test_correct = [], []
best_image_embedding_per_model, image_embedding_list = {}, {}
overalMaxAccuracy = 0
image_labels = {}
cnt =0
# Setting hyper parameters
# 1. set layers that we want to normalize - tune this
batchNormLayers = [["l1","l2","l3","l4","l5"], ["l1","l2"],["l1","l3","l4"]]
# 2. set activation functions to tune
actFuns = ["tanh", "relu"]
# 3. filter size to tune
filter_sizes = [5,3]
# run 3 loops - to perform tuning of the above three hyper parameters
for normLayers in batchNormLayers:
    for actFun in actFuns:
        for filter_size in filter_sizes:
            model_name = f"CNNImagemodel_{'_'.join(normLayers)}_{actFun}_{filter_size}"
            image_embedding_list[model_name] = []
            image_labels[model_name] = []
            torch.manual_seed(41)
            # declare the model with each parameter picked by loop iteration
            # replcae CNNImagemodel
            model = CNNModel(filter_size, normLayers, actFun)
            
            criterion = nn.CrossEntropyLoss()
            optimizer = torch.optim.Adam(model.parameters(), lr = 0.0001)

            for i in range(epochs):
                train_corr = 0
                test_corr = 0

                for b, (X_train, y_train) in enumerate(train_loader_images):
                    # Reshape input data to 4D
                    X_train = X_train.view(-1, 1, 28, 28)

                    y_pred, image_embedding = model(X_train)
                    #print(image_embedding.shape)
                    if i == epochs-1:
                        #print('here')
                        image_embedding_list[model_name].append(image_embedding)
                        cnt+=1
                        image_labels[model_name].append(y_train)
                        # put in a dict with model name and pick for best model
                    y_train = y_train.long()
                    loss = criterion(y_pred, y_train)
                    # make predictions
                    predicted = torch.max(y_pred.data, 1)[1]
                    batch_corr = (predicted == y_train).sum()
                    train_corr += batch_corr

                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()

                    if b % 600 == 0:
                        print("epoch: ", i)
                        print("batch: ", b)
                        print("loss: ", loss.item())

                #image_embedding_list.append(image_embedding[:-1])
                train_losses.append(loss)
                train_correct.append(train_corr)

                # Calculate training accuracy
                train_accuracy = train_corr.item() / len(train_loader_images.dataset)

                # Testing
                test_pred = []
                test_true = []
                with torch.no_grad(): # no training anymore
                    for b, (X_test, y_test) in enumerate(valid_loader_images):
                        X_test = X_test.view(-1, 1, 28, 28)
                        y_val, _ = model(X_test)
                        y_test = y_test.long()
                        predicted = torch.max(y_val.data, 1)[1]
                        test_pred.extend(predicted.tolist())
                        test_true.extend(y_test.tolist())

                    test_pred = torch.tensor(test_pred)
                    test_true = torch.tensor(test_true)

                    batch_size = X_test.size(0)  # Get the actual batch size
                    if batch_size == len(y_test):  # Check if this is the last batch
                        test_accuracy = torch.sum(predicted == y_test).item() / batch_size
                        loss = criterion(y_val, y_test)
                    else:
                        test_accuracy = torch.sum(predicted == y_test[:batch_size]).item() / batch_size
                        loss = criterion(y_val, y_test[:batch_size])

                test_losses.append(loss)
                test_correct.append(torch.sum(test_pred == test_true))
                # Calculate testing accuracy
                test_accuracy = torch.sum(test_pred == test_true).item() / len(valid_loader_images.dataset)
                
                # basically get embeddings for the last batch of the 9th epoch
                
                
                
                if test_accuracy > overalMaxAccuracy and i == epochs-1:
                    bestModel = model
                    bestModel_name = model_name
                    overalMaxAccuracy = test_accuracy
                    best_image_embedding_per_model[model_name] = image_embedding
                    # can get 3 of the following from dict
#                     image_embedding_best_model = image_embedding
#                     best_image_embedding_list = image_embedding_list
#                     best_image_labels = image_labels

                print("Using Normalization for layers: ", normLayers, "Activation Fucntion: ", actFun, "filter size: ", filter_size)
                print(f"Epoch {i+1}/{epochs}, Training Accuracy: {train_accuracy:.4f}, Testing Accuracy: {test_accuracy:.4f}")

current_time = time.time()
total_time = current_time - start_time
print("Training time: ", total_time/60, "mins")
# Out:
# epoch:  0
# batch:  0
# loss:  2.289210081100464
# epoch:  0
# batch:  600
# loss:  0.4925999343395233
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  tanh filter size:  5
# Epoch 1/10, Training Accuracy: 0.6981, Testing Accuracy: 0.8421
# epoch:  1
# batch:  0
# loss:  0.3123425543308258
# epoch:  1
# batch:  600
# loss:  0.34435799717903137
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  tanh filter size:  5
# Epoch 2/10, Training Accuracy: 0.8585, Testing Accuracy: 0.8600
# epoch:  2
# batch:  0
# loss:  0.26120394468307495
# epoch:  2
# batch:  600
# loss:  0.32163727283477783
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  tanh filter size:  5
# Epoch 3/10, Training Accuracy: 0.8684, Testing Accuracy: 0.8648
# epoch:  3
# batch:  0
# loss:  0.2746165990829468
# epoch:  3
# batch:  600
# loss:  0.32062050700187683
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  tanh filter size:  5
# Epoch 4/10, Training Accuracy: 0.8729, Testing Accuracy: 0.8672
# epoch:  4
# batch:  0
# loss:  0.28617796301841736
# epoch:  4
# batch:  600
# loss:  0.31885409355163574
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  tanh filter size:  5
# Epoch 5/10, Training Accuracy: 0.8762, Testing Accuracy: 0.8684
# epoch:  5
# batch:  0
# loss:  0.26782846450805664
# epoch:  5
# batch:  600
# loss:  0.30355319380760193
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  tanh filter size:  5
# Epoch 6/10, Training Accuracy: 0.8788, Testing Accuracy: 0.8686
# epoch:  6
# batch:  0
# loss:  0.2490592747926712
# epoch:  6
# batch:  600
# loss:  0.28071534633636475
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  tanh filter size:  5
# Epoch 7/10, Training Accuracy: 0.8805, Testing Accuracy: 0.8696
# epoch:  7
# batch:  0
# loss:  0.26182034611701965
# epoch:  7
# batch:  600
# loss:  0.25851765275001526
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  tanh filter size:  5
# Epoch 8/10, Training Accuracy: 0.8817, Testing Accuracy: 0.8691
# epoch:  8
# batch:  0
# loss:  0.23333872854709625
# epoch:  8
# batch:  600
# loss:  0.24255597591400146
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  tanh filter size:  5
# Epoch 9/10, Training Accuracy: 0.8825, Testing Accuracy: 0.8698
# epoch:  9
# batch:  0
# loss:  0.25774186849594116
# epoch:  9
# batch:  600
# loss:  0.26778894662857056
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  tanh filter size:  5
# Epoch 10/10, Training Accuracy: 0.8837, Testing Accuracy: 0.8704
# epoch:  0
# batch:  0
# loss:  2.3026225566864014
# epoch:  0
# batch:  600
# loss:  0.23230119049549103
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  tanh filter size:  3
# Epoch 1/10, Training Accuracy: 0.8031, Testing Accuracy: 0.9497
# epoch:  1
# batch:  0
# loss:  0.1722724437713623
# epoch:  1
# batch:  600
# loss:  0.17595010995864868
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  tanh filter size:  3
# Epoch 2/10, Training Accuracy: 0.9668, Testing Accuracy: 0.9677
# epoch:  2
# batch:  0
# loss:  0.09854847192764282
# epoch:  2
# batch:  600
# loss:  0.10200972855091095
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  tanh filter size:  3
# Epoch 3/10, Training Accuracy: 0.9778, Testing Accuracy: 0.9754
# epoch:  3
# batch:  0
# loss:  0.06197996065020561
# epoch:  3
# batch:  600
# loss:  0.14357905089855194
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  tanh filter size:  3
# Epoch 4/10, Training Accuracy: 0.9826, Testing Accuracy: 0.9769
# epoch:  4
# batch:  0
# loss:  0.04822063073515892
# epoch:  4
# batch:  600
# loss:  0.13282577693462372
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  tanh filter size:  3
# Epoch 5/10, Training Accuracy: 0.9856, Testing Accuracy: 0.9807
# epoch:  5
# batch:  0
# loss:  0.0392095148563385
# epoch:  5
# batch:  600
# loss:  0.12716680765151978
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  tanh filter size:  3
# Epoch 6/10, Training Accuracy: 0.9874, Testing Accuracy: 0.9814
# epoch:  6
# batch:  0
# loss:  0.02234632521867752
# epoch:  6
# batch:  600
# loss:  0.11498056352138519
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  tanh filter size:  3
# Epoch 7/10, Training Accuracy: 0.9892, Testing Accuracy: 0.9830
# epoch:  7
# batch:  0
# loss:  0.023743029683828354
# epoch:  7
# batch:  600
# loss:  0.07453995198011398
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  tanh filter size:  3
# Epoch 8/10, Training Accuracy: 0.9907, Testing Accuracy: 0.9832
# epoch:  8
# batch:  0
# loss:  0.020225191488862038
# epoch:  8
# batch:  600
# loss:  0.058188699185848236
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  tanh filter size:  3
# Epoch 9/10, Training Accuracy: 0.9918, Testing Accuracy: 0.9838
# epoch:  9
# batch:  0
# loss:  0.009145819582045078
# epoch:  9
# batch:  600
# loss:  0.056996118277311325
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  tanh filter size:  3
# Epoch 10/10, Training Accuracy: 0.9929, Testing Accuracy: 0.9848
# epoch:  0
# batch:  0
# loss:  2.2970190048217773
# epoch:  0
# batch:  600
# loss:  0.49018001556396484
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  relu filter size:  5
# Epoch 1/10, Training Accuracy: 0.6786, Testing Accuracy: 0.7696
# epoch:  1
# batch:  0
# loss:  0.5433328747749329
# epoch:  1
# batch:  600
# loss:  0.44716373085975647
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  relu filter size:  5
# Epoch 2/10, Training Accuracy: 0.7801, Testing Accuracy: 0.7772
# epoch:  2
# batch:  0
# loss:  0.4887515604496002
# epoch:  2
# batch:  600
# loss:  0.4686278700828552
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  relu filter size:  5
# Epoch 3/10, Training Accuracy: 0.7871, Testing Accuracy: 0.7789
# epoch:  3
# batch:  0
# loss:  0.48681706190109253
# epoch:  3
# batch:  600
# loss:  0.4468066692352295
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  relu filter size:  5
# Epoch 4/10, Training Accuracy: 0.7904, Testing Accuracy: 0.7818
# epoch:  4
# batch:  0
# loss:  0.49730271100997925
# epoch:  4
# batch:  600
# loss:  0.4365372061729431
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  relu filter size:  5
# Epoch 5/10, Training Accuracy: 0.7930, Testing Accuracy: 0.7813
# epoch:  5
# batch:  0
# loss:  0.4802878201007843
# epoch:  5
# batch:  600
# loss:  0.4098624885082245
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  relu filter size:  5
# Epoch 6/10, Training Accuracy: 0.7941, Testing Accuracy: 0.7817
# epoch:  6
# batch:  0
# loss:  0.4700925946235657
# epoch:  6
# batch:  600
# loss:  0.3926084637641907
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  relu filter size:  5
# Epoch 7/10, Training Accuracy: 0.7955, Testing Accuracy: 0.7823
# epoch:  7
# batch:  0
# loss:  0.4767954349517822
# epoch:  7
# batch:  600
# loss:  0.37885743379592896
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  relu filter size:  5
# Epoch 8/10, Training Accuracy: 0.7962, Testing Accuracy: 0.7826
# epoch:  8
# batch:  0
# loss:  0.47268813848495483
# epoch:  8
# batch:  600
# loss:  0.3676307797431946
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  relu filter size:  5
# Epoch 9/10, Training Accuracy: 0.7964, Testing Accuracy: 0.7813
# epoch:  9
# batch:  0
# loss:  0.4777389168739319
# epoch:  9
# batch:  600
# loss:  0.3658018708229065
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  relu filter size:  5
# Epoch 10/10, Training Accuracy: 0.7967, Testing Accuracy: 0.7814
# epoch:  0
# batch:  0
# loss:  2.302204132080078
# epoch:  0
# batch:  600
# loss:  0.13642039895057678
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  relu filter size:  3
# Epoch 1/10, Training Accuracy: 0.8922, Testing Accuracy: 0.9684
# epoch:  1
# batch:  0
# loss:  0.06383928656578064
# epoch:  1
# batch:  600
# loss:  0.11492794007062912
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  relu filter size:  3
# Epoch 2/10, Training Accuracy: 0.9778, Testing Accuracy: 0.9787
# epoch:  2
# batch:  0
# loss:  0.044551387429237366
# epoch:  2
# batch:  600
# loss:  0.045045461505651474
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  relu filter size:  3
# Epoch 3/10, Training Accuracy: 0.9854, Testing Accuracy: 0.9814
# epoch:  3
# batch:  0
# loss:  0.017355991527438164
# epoch:  3
# batch:  600
# loss:  0.04854685440659523
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  relu filter size:  3
# Epoch 4/10, Training Accuracy: 0.9892, Testing Accuracy: 0.9821
# epoch:  4
# batch:  0
# loss:  0.008846280165016651
# epoch:  4
# batch:  600
# loss:  0.0262971930205822
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  relu filter size:  3
# Epoch 5/10, Training Accuracy: 0.9921, Testing Accuracy: 0.9848
# epoch:  5
# batch:  0
# loss:  0.006982652470469475
# epoch:  5
# batch:  600
# loss:  0.02682351879775524
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  relu filter size:  3
# Epoch 6/10, Training Accuracy: 0.9936, Testing Accuracy: 0.9839
# epoch:  6
# batch:  0
# loss:  0.0025900844484567642
# epoch:  6
# batch:  600
# loss:  0.009767619892954826
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  relu filter size:  3
# Epoch 7/10, Training Accuracy: 0.9954, Testing Accuracy: 0.9859
# epoch:  7
# batch:  0
# loss:  0.0016893417341634631
# epoch:  7
# batch:  600
# loss:  0.010544000193476677
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  relu filter size:  3
# Epoch 8/10, Training Accuracy: 0.9966, Testing Accuracy: 0.9848
# epoch:  8
# batch:  0
# loss:  0.0018549481173977256
# epoch:  8
# batch:  600
# loss:  0.003780573373660445
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  relu filter size:  3
# Epoch 9/10, Training Accuracy: 0.9974, Testing Accuracy: 0.9860
# epoch:  9
# batch:  0
# loss:  0.0015245178947225213
# epoch:  9
# batch:  600
# loss:  0.005221379920840263
# Using Normalization for layers:  ['l1', 'l2', 'l3', 'l4', 'l5'] Activation Fucntion:  relu filter size:  3
# Epoch 10/10, Training Accuracy: 0.9978, Testing Accuracy: 0.9857
# epoch:  0
# batch:  0
# loss:  2.29683256149292
# epoch:  0
# batch:  600
# loss:  0.5627601742744446
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  tanh filter size:  5
# Epoch 1/10, Training Accuracy: 0.6446, Testing Accuracy: 0.8165
# epoch:  1
# batch:  0
# loss:  0.38296180963516235
# epoch:  1
# batch:  600
# loss:  0.38536563515663147
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  tanh filter size:  5
# Epoch 2/10, Training Accuracy: 0.8381, Testing Accuracy: 0.8459
# epoch:  2
# batch:  0
# loss:  0.32630497217178345
# epoch:  2
# batch:  600
# loss:  0.356204092502594
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  tanh filter size:  5
# Epoch 3/10, Training Accuracy: 0.8560, Testing Accuracy: 0.8548
# epoch:  3
# batch:  0
# loss:  0.30604255199432373
# epoch:  3
# batch:  600
# loss:  0.29957079887390137
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  tanh filter size:  5
# Epoch 4/10, Training Accuracy: 0.8638, Testing Accuracy: 0.8588
# epoch:  4
# batch:  0
# loss:  0.3207690715789795
# epoch:  4
# batch:  600
# loss:  0.32249003648757935
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  tanh filter size:  5
# Epoch 5/10, Training Accuracy: 0.8686, Testing Accuracy: 0.8629
# epoch:  5
# batch:  0
# loss:  0.2985476553440094
# epoch:  5
# batch:  600
# loss:  0.3151693046092987
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  tanh filter size:  5
# Epoch 6/10, Training Accuracy: 0.8715, Testing Accuracy: 0.8648
# epoch:  6
# batch:  0
# loss:  0.27850106358528137
# epoch:  6
# batch:  600
# loss:  0.33893126249313354
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  tanh filter size:  5
# Epoch 7/10, Training Accuracy: 0.8736, Testing Accuracy: 0.8643
# epoch:  7
# batch:  0
# loss:  0.27747586369514465
# epoch:  7
# batch:  600
# loss:  0.2906903326511383
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  tanh filter size:  5
# Epoch 8/10, Training Accuracy: 0.8751, Testing Accuracy: 0.8657
# epoch:  8
# batch:  0
# loss:  0.2545177638530731
# epoch:  8
# batch:  600
# loss:  0.3424649238586426
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  tanh filter size:  5
# Epoch 9/10, Training Accuracy: 0.8773, Testing Accuracy: 0.8681
# epoch:  9
# batch:  0
# loss:  0.25758418440818787
# epoch:  9
# batch:  600
# loss:  0.32912325859069824
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  tanh filter size:  5
# Epoch 10/10, Training Accuracy: 0.8790, Testing Accuracy: 0.8698
# epoch:  0
# batch:  0
# loss:  2.3021059036254883
# epoch:  0
# batch:  600
# loss:  0.4740909934043884
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  tanh filter size:  3
# Epoch 1/10, Training Accuracy: 0.7123, Testing Accuracy: 0.8297
# epoch:  1
# batch:  0
# loss:  0.4299700856208801
# epoch:  1
# batch:  600
# loss:  0.4401441812515259
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  tanh filter size:  3
# Epoch 2/10, Training Accuracy: 0.8496, Testing Accuracy: 0.8564
# epoch:  2
# batch:  0
# loss:  0.38081803917884827
# epoch:  2
# batch:  600
# loss:  0.380380243062973
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  tanh filter size:  3
# Epoch 3/10, Training Accuracy: 0.8691, Testing Accuracy: 0.8658
# epoch:  3
# batch:  0
# loss:  0.3544698655605316
# epoch:  3
# batch:  600
# loss:  0.41204914450645447
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  tanh filter size:  3
# Epoch 4/10, Training Accuracy: 0.8762, Testing Accuracy: 0.8720
# epoch:  4
# batch:  0
# loss:  0.3722115159034729
# epoch:  4
# batch:  600
# loss:  0.4052554666996002
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  tanh filter size:  3
# Epoch 5/10, Training Accuracy: 0.8811, Testing Accuracy: 0.8771
# epoch:  5
# batch:  0
# loss:  0.3533593714237213
# epoch:  5
# batch:  600
# loss:  0.4181109368801117
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  tanh filter size:  3
# Epoch 6/10, Training Accuracy: 0.8846, Testing Accuracy: 0.8776
# epoch:  6
# batch:  0
# loss:  0.30965712666511536
# epoch:  6
# batch:  600
# loss:  0.40917542576789856
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  tanh filter size:  3
# Epoch 7/10, Training Accuracy: 0.8873, Testing Accuracy: 0.8786
# epoch:  7
# batch:  0
# loss:  0.35644015669822693
# epoch:  7
# batch:  600
# loss:  0.3997316062450409
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  tanh filter size:  3
# Epoch 8/10, Training Accuracy: 0.8887, Testing Accuracy: 0.8807
# epoch:  8
# batch:  0
# loss:  0.30056729912757874
# epoch:  8
# batch:  600
# loss:  0.37385717034339905
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  tanh filter size:  3
# Epoch 9/10, Training Accuracy: 0.8898, Testing Accuracy: 0.8818
# epoch:  9
# batch:  0
# loss:  0.2981170117855072
# epoch:  9
# batch:  600
# loss:  0.3398359715938568
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  tanh filter size:  3
# Epoch 10/10, Training Accuracy: 0.8915, Testing Accuracy: 0.8847
# epoch:  0
# batch:  0
# loss:  2.299123764038086
# epoch:  0
# batch:  600
# loss:  0.29870617389678955
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  relu filter size:  5
# Epoch 1/10, Training Accuracy: 0.6792, Testing Accuracy: 0.9272
# epoch:  1
# batch:  0
# loss:  0.13886524736881256
# epoch:  1
# batch:  600
# loss:  0.15905128419399261
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  relu filter size:  5
# Epoch 2/10, Training Accuracy: 0.9479, Testing Accuracy: 0.9544
# epoch:  2
# batch:  0
# loss:  0.11000626534223557
# epoch:  2
# batch:  600
# loss:  0.16609561443328857
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  relu filter size:  5
# Epoch 3/10, Training Accuracy: 0.9662, Testing Accuracy: 0.9658
# epoch:  3
# batch:  0
# loss:  0.1027008518576622
# epoch:  3
# batch:  600
# loss:  0.12089776247739792
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  relu filter size:  5
# Epoch 4/10, Training Accuracy: 0.9741, Testing Accuracy: 0.9703
# epoch:  4
# batch:  0
# loss:  0.1420845091342926
# epoch:  4
# batch:  600
# loss:  0.12797066569328308
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  relu filter size:  5
# Epoch 5/10, Training Accuracy: 0.9789, Testing Accuracy: 0.9750
# epoch:  5
# batch:  0
# loss:  0.1079704537987709
# epoch:  5
# batch:  600
# loss:  0.09868322312831879
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  relu filter size:  5
# Epoch 6/10, Training Accuracy: 0.9821, Testing Accuracy: 0.9782
# epoch:  6
# batch:  0
# loss:  0.0874965637922287
# epoch:  6
# batch:  600
# loss:  0.09130553156137466
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  relu filter size:  5
# Epoch 7/10, Training Accuracy: 0.9845, Testing Accuracy: 0.9794
# epoch:  7
# batch:  0
# loss:  0.08315356075763702
# epoch:  7
# batch:  600
# loss:  0.053547248244285583
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  relu filter size:  5
# Epoch 8/10, Training Accuracy: 0.9857, Testing Accuracy: 0.9783
# epoch:  8
# batch:  0
# loss:  0.06279422342777252
# epoch:  8
# batch:  600
# loss:  0.092503622174263
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  relu filter size:  5
# Epoch 9/10, Training Accuracy: 0.9865, Testing Accuracy: 0.9812
# epoch:  9
# batch:  0
# loss:  0.06660502403974533
# epoch:  9
# batch:  600
# loss:  0.07343994081020355
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  relu filter size:  5
# Epoch 10/10, Training Accuracy: 0.9884, Testing Accuracy: 0.9824
# epoch:  0
# batch:  0
# loss:  2.3046011924743652
# epoch:  0
# batch:  600
# loss:  0.19973677396774292
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  relu filter size:  3
# Epoch 1/10, Training Accuracy: 0.8055, Testing Accuracy: 0.9528
# epoch:  1
# batch:  0
# loss:  0.16824570298194885
# epoch:  1
# batch:  600
# loss:  0.2311183512210846
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  relu filter size:  3
# Epoch 2/10, Training Accuracy: 0.9650, Testing Accuracy: 0.9662
# epoch:  2
# batch:  0
# loss:  0.12972471117973328
# epoch:  2
# batch:  600
# loss:  0.13528068363666534
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  relu filter size:  3
# Epoch 3/10, Training Accuracy: 0.9745, Testing Accuracy: 0.9699
# epoch:  3
# batch:  0
# loss:  0.10760544240474701
# epoch:  3
# batch:  600
# loss:  0.13448646664619446
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  relu filter size:  3
# Epoch 4/10, Training Accuracy: 0.9799, Testing Accuracy: 0.9732
# epoch:  4
# batch:  0
# loss:  0.11020269989967346
# epoch:  4
# batch:  600
# loss:  0.15365999937057495
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  relu filter size:  3
# Epoch 5/10, Training Accuracy: 0.9830, Testing Accuracy: 0.9788
# epoch:  5
# batch:  0
# loss:  0.08380758762359619
# epoch:  5
# batch:  600
# loss:  0.15452419221401215
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  relu filter size:  3
# Epoch 6/10, Training Accuracy: 0.9849, Testing Accuracy: 0.9796
# epoch:  6
# batch:  0
# loss:  0.06356657296419144
# epoch:  6
# batch:  600
# loss:  0.15592196583747864
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  relu filter size:  3
# Epoch 7/10, Training Accuracy: 0.9872, Testing Accuracy: 0.9818
# epoch:  7
# batch:  0
# loss:  0.02985265664756298
# epoch:  7
# batch:  600
# loss:  0.09204433858394623
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  relu filter size:  3
# Epoch 8/10, Training Accuracy: 0.9884, Testing Accuracy: 0.9819
# epoch:  8
# batch:  0
# loss:  0.011429646983742714
# epoch:  8
# batch:  600
# loss:  0.05278344079852104
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  relu filter size:  3
# Epoch 9/10, Training Accuracy: 0.9892, Testing Accuracy: 0.9834
# epoch:  9
# batch:  0
# loss:  0.02393181622028351
# epoch:  9
# batch:  600
# loss:  0.07473619282245636
# Using Normalization for layers:  ['l1', 'l2'] Activation Fucntion:  relu filter size:  3
# Epoch 10/10, Training Accuracy: 0.9904, Testing Accuracy: 0.9846
# epoch:  0
# batch:  0
# loss:  2.294577121734619
# epoch:  0
# batch:  600
# loss:  0.9116717576980591
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  tanh filter size:  5
# Epoch 1/10, Training Accuracy: 0.6033, Testing Accuracy: 0.6612
# epoch:  1
# batch:  0
# loss:  0.8254218101501465
# epoch:  1
# batch:  600
# loss:  0.8274911642074585
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  tanh filter size:  5
# Epoch 2/10, Training Accuracy: 0.6811, Testing Accuracy: 0.6733
# epoch:  2
# batch:  0
# loss:  0.7662617564201355
# epoch:  2
# batch:  600
# loss:  0.8193565607070923
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  tanh filter size:  5
# Epoch 3/10, Training Accuracy: 0.6876, Testing Accuracy: 0.6783
# epoch:  3
# batch:  0
# loss:  0.7557070851325989
# epoch:  3
# batch:  600
# loss:  0.7891075015068054
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  tanh filter size:  5
# Epoch 4/10, Training Accuracy: 0.6911, Testing Accuracy: 0.6803
# epoch:  4
# batch:  0
# loss:  0.7599058747291565
# epoch:  4
# batch:  600
# loss:  0.8014292120933533
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  tanh filter size:  5
# Epoch 5/10, Training Accuracy: 0.6932, Testing Accuracy: 0.6807
# epoch:  5
# batch:  0
# loss:  0.7556663155555725
# epoch:  5
# batch:  600
# loss:  0.774662971496582
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  tanh filter size:  5
# Epoch 6/10, Training Accuracy: 0.6945, Testing Accuracy: 0.6816
# epoch:  6
# batch:  0
# loss:  0.7453291416168213
# epoch:  6
# batch:  600
# loss:  0.7010406255722046
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  tanh filter size:  5
# Epoch 7/10, Training Accuracy: 0.7221, Testing Accuracy: 0.7691
# epoch:  7
# batch:  0
# loss:  0.4930366575717926
# epoch:  7
# batch:  600
# loss:  0.6335816383361816
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  tanh filter size:  5
# Epoch 8/10, Training Accuracy: 0.7829, Testing Accuracy: 0.7702
# epoch:  8
# batch:  0
# loss:  0.47467049956321716
# epoch:  8
# batch:  600
# loss:  0.26408350467681885
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  tanh filter size:  5
# Epoch 9/10, Training Accuracy: 0.8614, Testing Accuracy: 0.8667
# epoch:  9
# batch:  0
# loss:  0.25804081559181213
# epoch:  9
# batch:  600
# loss:  0.23774155974388123
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  tanh filter size:  5
# Epoch 10/10, Training Accuracy: 0.8791, Testing Accuracy: 0.8695
# epoch:  0
# batch:  0
# loss:  2.301412343978882
# epoch:  0
# batch:  600
# loss:  0.5153542160987854
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  tanh filter size:  3
# Epoch 1/10, Training Accuracy: 0.6915, Testing Accuracy: 0.7702
# epoch:  1
# batch:  0
# loss:  0.46923449635505676
# epoch:  1
# batch:  600
# loss:  0.45176100730895996
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  tanh filter size:  3
# Epoch 2/10, Training Accuracy: 0.8584, Testing Accuracy: 0.8678
# epoch:  2
# batch:  0
# loss:  0.3731668293476105
# epoch:  2
# batch:  600
# loss:  0.3785029351711273
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  tanh filter size:  3
# Epoch 3/10, Training Accuracy: 0.8767, Testing Accuracy: 0.8725
# epoch:  3
# batch:  0
# loss:  0.34214285016059875
# epoch:  3
# batch:  600
# loss:  0.406199187040329
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  tanh filter size:  3
# Epoch 4/10, Training Accuracy: 0.8818, Testing Accuracy: 0.8771
# epoch:  4
# batch:  0
# loss:  0.33745989203453064
# epoch:  4
# batch:  600
# loss:  0.39963498711586
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  tanh filter size:  3
# Epoch 5/10, Training Accuracy: 0.8849, Testing Accuracy: 0.8800
# epoch:  5
# batch:  0
# loss:  0.3283619284629822
# epoch:  5
# batch:  600
# loss:  0.3975527286529541
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  tanh filter size:  3
# Epoch 6/10, Training Accuracy: 0.8877, Testing Accuracy: 0.8806
# epoch:  6
# batch:  0
# loss:  0.2951022982597351
# epoch:  6
# batch:  600
# loss:  0.3698848783969879
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  tanh filter size:  3
# Epoch 7/10, Training Accuracy: 0.8898, Testing Accuracy: 0.8823
# epoch:  7
# batch:  0
# loss:  0.31901639699935913
# epoch:  7
# batch:  600
# loss:  0.31976890563964844
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  tanh filter size:  3
# Epoch 8/10, Training Accuracy: 0.8911, Testing Accuracy: 0.8834
# epoch:  8
# batch:  0
# loss:  0.28231382369995117
# epoch:  8
# batch:  600
# loss:  0.32488706707954407
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  tanh filter size:  3
# Epoch 9/10, Training Accuracy: 0.8926, Testing Accuracy: 0.8849
# epoch:  9
# batch:  0
# loss:  0.2912384271621704
# epoch:  9
# batch:  600
# loss:  0.29797467589378357
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  tanh filter size:  3
# Epoch 10/10, Training Accuracy: 0.8938, Testing Accuracy: 0.8867
# epoch:  0
# batch:  0
# loss:  2.29864501953125
# epoch:  0
# batch:  600
# loss:  0.2531697154045105
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  relu filter size:  5
# Epoch 1/10, Training Accuracy: 0.7271, Testing Accuracy: 0.9525
# epoch:  1
# batch:  0
# loss:  0.10597215592861176
# epoch:  1
# batch:  600
# loss:  0.09468261152505875
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  relu filter size:  5
# Epoch 2/10, Training Accuracy: 0.9702, Testing Accuracy: 0.9735
# epoch:  2
# batch:  0
# loss:  0.07253386080265045
# epoch:  2
# batch:  600
# loss:  0.11290283501148224
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  relu filter size:  5
# Epoch 3/10, Training Accuracy: 0.9809, Testing Accuracy: 0.9797
# epoch:  3
# batch:  0
# loss:  0.07075220346450806
# epoch:  3
# batch:  600
# loss:  0.06694810837507248
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  relu filter size:  5
# Epoch 4/10, Training Accuracy: 0.9854, Testing Accuracy: 0.9812
# epoch:  4
# batch:  0
# loss:  0.06212525814771652
# epoch:  4
# batch:  600
# loss:  0.0906001403927803
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  relu filter size:  5
# Epoch 5/10, Training Accuracy: 0.9883, Testing Accuracy: 0.9846
# epoch:  5
# batch:  0
# loss:  0.029031848534941673
# epoch:  5
# batch:  600
# loss:  0.08672308921813965
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  relu filter size:  5
# Epoch 6/10, Training Accuracy: 0.9901, Testing Accuracy: 0.9842
# epoch:  6
# batch:  0
# loss:  0.02280927076935768
# epoch:  6
# batch:  600
# loss:  0.12388315051794052
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  relu filter size:  5
# Epoch 7/10, Training Accuracy: 0.9920, Testing Accuracy: 0.9841
# epoch:  7
# batch:  0
# loss:  0.015266118571162224
# epoch:  7
# batch:  600
# loss:  0.07999182492494583
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  relu filter size:  5
# Epoch 8/10, Training Accuracy: 0.9931, Testing Accuracy: 0.9847
# epoch:  8
# batch:  0
# loss:  0.003355465829372406
# epoch:  8
# batch:  600
# loss:  0.09342896938323975
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  relu filter size:  5
# Epoch 9/10, Training Accuracy: 0.9944, Testing Accuracy: 0.9860
# epoch:  9
# batch:  0
# loss:  0.009017197415232658
# epoch:  9
# batch:  600
# loss:  0.08607099950313568
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  relu filter size:  5
# Epoch 10/10, Training Accuracy: 0.9951, Testing Accuracy: 0.9861
# epoch:  0
# batch:  0
# loss:  2.3005189895629883
# epoch:  0
# batch:  600
# loss:  0.46583032608032227
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  relu filter size:  3
# Epoch 1/10, Training Accuracy: 0.7523, Testing Accuracy: 0.8575
# epoch:  1
# batch:  0
# loss:  0.3972369134426117
# epoch:  1
# batch:  600
# loss:  0.47119221091270447
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  relu filter size:  3
# Epoch 2/10, Training Accuracy: 0.8680, Testing Accuracy: 0.8702
# epoch:  2
# batch:  0
# loss:  0.3722825050354004
# epoch:  2
# batch:  600
# loss:  0.3902401924133301
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  relu filter size:  3
# Epoch 3/10, Training Accuracy: 0.8791, Testing Accuracy: 0.8764
# epoch:  3
# batch:  0
# loss:  0.33880266547203064
# epoch:  3
# batch:  600
# loss:  0.4182470738887787
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  relu filter size:  3
# Epoch 4/10, Training Accuracy: 0.8831, Testing Accuracy: 0.8789
# epoch:  4
# batch:  0
# loss:  0.33550092577934265
# epoch:  4
# batch:  600
# loss:  0.3643450438976288
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  relu filter size:  3
# Epoch 5/10, Training Accuracy: 0.8867, Testing Accuracy: 0.8826
# epoch:  5
# batch:  0
# loss:  0.3234091103076935
# epoch:  5
# batch:  600
# loss:  0.35054251551628113
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  relu filter size:  3
# Epoch 6/10, Training Accuracy: 0.8889, Testing Accuracy: 0.8833
# epoch:  6
# batch:  0
# loss:  0.3118990659713745
# epoch:  6
# batch:  600
# loss:  0.31894612312316895
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  relu filter size:  3
# Epoch 7/10, Training Accuracy: 0.8904, Testing Accuracy: 0.8856
# epoch:  7
# batch:  0
# loss:  0.3082902431488037
# epoch:  7
# batch:  600
# loss:  0.320522665977478
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  relu filter size:  3
# Epoch 8/10, Training Accuracy: 0.8918, Testing Accuracy: 0.8856
# epoch:  8
# batch:  0
# loss:  0.3082132637500763
# epoch:  8
# batch:  600
# loss:  0.30265161395072937
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  relu filter size:  3
# Epoch 9/10, Training Accuracy: 0.8926, Testing Accuracy: 0.8866
# epoch:  9
# batch:  0
# loss:  0.30895811319351196
# epoch:  9
# batch:  600
# loss:  0.30044472217559814
# Using Normalization for layers:  ['l1', 'l3', 'l5'] Activation Fucntion:  relu filter size:  3
# Epoch 10/10, Training Accuracy: 0.8933, Testing Accuracy: 0.8878
# Training time:  32.934887949625654 mins

# %%
bestModel
# Out:
# CNNModel(
#   (conv1): Conv2d(1, 6, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(6, 12, kernel_size=(5, 5), stride=(1, 1))
#   (conv3): Conv2d(12, 24, kernel_size=(5, 5), stride=(1, 1))
#   (conv4): Conv2d(24, 48, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=48, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=10, bias=True)
#   (batch_norm1): BatchNorm2d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batch_norm3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout): Dropout(p=0.05, inplace=False)
# )

# %%
image_embedding_best_model = best_image_embedding_per_model[bestModel_name]
best_image_embedding_list = image_embedding_list[bestModel_name]
best_image_labels = image_labels[bestModel_name]

# %%
print(image_embedding_best_model.shape)
print(len(best_image_embedding_list))
print(len(best_image_labels))
# Out:
# torch.Size([64, 64])
# 750
# 750

# %% [raw]
# # final parameters:
#
# Image model: bestModel
#
# image train data: train_loader_images
# image test data: test_loader_images
#
# image embeddings: image_embedding_best_model
#
# all image embeddings = best_image_embedding_list

# %%
image_embedding_best_model.shape

image_embedding_np = image_embedding.detach().numpy()

# Convert NumPy array to DataFrame
df = pd.DataFrame(image_embedding_np)

# Export DataFrame to Excel
df.to_excel('image_embedding.xlsx', index=False)

# %%
# make predictions
predictedAll = []
with torch.no_grad():
    for X_test in test_loader_images:
        X_test = X_test[0]
        X_test = X_test.view(-1, 1, 28, 28)
        y_val, _ = bestModel(X_test)
        predicted = torch.max(y_val.data, 1)[1]
        predictedAll.append(predicted)

# Concatenate predictions from all batches
all_predictions = torch.cat(predictedAll, dim=0)

print(all_predictions.shape)
# Out:
# torch.Size([10000])

# %%
# export the data to excel
finalPreds = pd.DataFrame(all_predictions, columns=["preds"])
finalPreds.to_csv("img_preds.csv", index=False)

# %%
# new
class RNNAudioModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(RNNAudioModel, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, batch_first=True, nonlinearity='relu')
        self.fc1 = nn.Linear(hidden_size, 100)
        self.bn1 = nn.BatchNorm1d(100)
        self.fc2 = nn.Linear(100, 64)
        self.bn2 = nn.BatchNorm1d(64)
        self.fc3 = nn.Linear(64, num_classes)
        self.bn3 = nn.BatchNorm1d(num_classes)

    def forward(self, x):
        batch_size = x.size(0)
        seq_len = x.size(1)
        
        # Reshape input tensor to have shape (batch_size, seq_len, input_size)
        x = x.unsqueeze(1).repeat(1, seq_len, 1)
        
        h0 = torch.zeros(self.num_layers, batch_size, self.hidden_size)
        out, _ = self.rnn(x, h0)
        out = self.fc1(out[:, -1, :])
        out = self.bn1(out)
        out = torch.relu(out)
        out = self.fc2(out)
        out1 = self.bn2(out)
        out = self.fc3(out1)
        out = self.bn3(out)
        return out, out1

# %%
input_size = x_train_audio.shape[1]
hidden_size_list = [320,350,400] #[128,320] # best - 320
num_layers_list = [1,2]
num_classes = 10  # there are 10 output classes representing digits 0-9
learning_rate = 0.0001

# %%
# Training

start_time = time.time()
best_audio_embedding_per_model, audio_embedding_list = {}, {}
audio_labels = {}
num_epochs = 25
max_valid_accuracy = 0

for hidden_size in hidden_size_list:
    for num_layers in num_layers_list:
        RNNmodel = RNNAudioModel(input_size, hidden_size, num_layers, num_classes)
        criterion = nn.CrossEntropyLoss()
        optimizer = torch.optim.Adam(RNNmodel.parameters(), lr=learning_rate)
        model_name = f"RNNmodel_{'_'.join(normLayers)}_{actFun}_{filter_size}"
        audio_embedding_list[model_name] = []
        audio_labels[model_name] = []
        
        for epoch in range(num_epochs):
            RNNmodel.train()
            train_loss = 0.0
            train_correct = 0
            train_total = 0

            for batch_idx, (inputs, labels) in enumerate(train_loader_audios):
                inputs, labels = inputs, labels

                optimizer.zero_grad()
                outputs, audio_embedding = RNNmodel(inputs)
                if epoch== num_epochs-1:
                    audio_embedding_list[model_name].append(audio_embedding)
                    audio_labels[model_name].append(labels)
                # Convert labels to Long data type
                labels = labels.long()

                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()

                train_loss += loss.item() * inputs.size(0)  # Multiply by batch size to get total loss
                _, predicted = outputs.max(1)
                train_correct += predicted.eq(labels).sum().item()
                train_total += labels.size(0)  # Increment total by batch size

            train_loss /= len(train_loader_audios.dataset)  # Divide by total number of samples
            train_acc = train_correct / train_total

            # Validation
            RNNmodel.eval()
            valid_loss = 0.0
            valid_correct = 0
            valid_total = 0

            with torch.no_grad():
                for b, (inputs, labels) in enumerate(valid_loader_audios):
                    inputs, labels = inputs, labels
                    outputs, _ = RNNmodel(inputs)

                    # Convert labels to Long data type
                    labels = labels.long()

                    loss = criterion(outputs, labels)

                    valid_loss += loss.item() * inputs.size(0)  # Multiply by batch size to get total loss
                    _, predicted = outputs.max(1)
                    valid_correct += predicted.eq(labels).sum().item()
                    valid_total += labels.size(0)  # Increment total by batch size

            valid_loss /= len(valid_loader_audios.dataset)  # Divide by total number of samples
            valid_acc = valid_correct / valid_total
            
            if valid_acc*100 > max_valid_accuracy*100 and epoch == num_epochs-1:
                max_valid_accuracy = valid_acc
                best_model = RNNmodel
                best_model_name = model_name
                best_audio_embedding_per_model[model_name] = audio_embedding
                
            print("Using hidden size of: ",hidden_size,"num layers: ", num_layers)   
            print(f"Epoch [{epoch+1}/{num_epochs}], "
                  f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, "
                  f"Valid Loss: {valid_loss:.4f}, Valid Acc: {valid_acc:.4f}")

current_time = time.time()
total_time = current_time - start_time
print("Training time:", total_time/60, "mins")
# Out:
# Using hidden size of:  320 num layers:  1
# Epoch [1/25], Train Loss: 1.2827, Train Acc: 0.6314, Valid Loss: 0.9571, Valid Acc: 0.7777
# Using hidden size of:  320 num layers:  1
# Epoch [2/25], Train Loss: 0.8947, Train Acc: 0.7969, Valid Loss: 0.7977, Valid Acc: 0.8275
# Using hidden size of:  320 num layers:  1
# Epoch [3/25], Train Loss: 0.7697, Train Acc: 0.8402, Valid Loss: 0.7139, Valid Acc: 0.8518
# Using hidden size of:  320 num layers:  1
# Epoch [4/25], Train Loss: 0.6899, Train Acc: 0.8615, Valid Loss: 0.6691, Valid Acc: 0.8598
# Using hidden size of:  320 num layers:  1
# Epoch [5/25], Train Loss: 0.6293, Train Acc: 0.8767, Valid Loss: 0.6067, Valid Acc: 0.8748
# Using hidden size of:  320 num layers:  1
# Epoch [6/25], Train Loss: 0.5804, Train Acc: 0.8888, Valid Loss: 0.5669, Valid Acc: 0.8830
# Using hidden size of:  320 num layers:  1
# Epoch [7/25], Train Loss: 0.5394, Train Acc: 0.8990, Valid Loss: 0.5379, Valid Acc: 0.8871
# Using hidden size of:  320 num layers:  1
# Epoch [8/25], Train Loss: 0.5039, Train Acc: 0.9066, Valid Loss: 0.5112, Valid Acc: 0.8936
# Using hidden size of:  320 num layers:  1
# Epoch [9/25], Train Loss: 0.4724, Train Acc: 0.9137, Valid Loss: 0.4883, Valid Acc: 0.8967
# Using hidden size of:  320 num layers:  1
# Epoch [10/25], Train Loss: 0.4440, Train Acc: 0.9191, Valid Loss: 0.4669, Valid Acc: 0.9004
# Using hidden size of:  320 num layers:  1
# Epoch [11/25], Train Loss: 0.4183, Train Acc: 0.9249, Valid Loss: 0.4522, Valid Acc: 0.9008
# Using hidden size of:  320 num layers:  1
# Epoch [12/25], Train Loss: 0.3949, Train Acc: 0.9301, Valid Loss: 0.4342, Valid Acc: 0.9034
# Using hidden size of:  320 num layers:  1
# Epoch [13/25], Train Loss: 0.3734, Train Acc: 0.9353, Valid Loss: 0.4180, Valid Acc: 0.9062
# Using hidden size of:  320 num layers:  1
# Epoch [14/25], Train Loss: 0.3535, Train Acc: 0.9401, Valid Loss: 0.4041, Valid Acc: 0.9086
# Using hidden size of:  320 num layers:  1
# Epoch [15/25], Train Loss: 0.3349, Train Acc: 0.9438, Valid Loss: 0.3885, Valid Acc: 0.9126
# Using hidden size of:  320 num layers:  1
# Epoch [16/25], Train Loss: 0.3179, Train Acc: 0.9477, Valid Loss: 0.3754, Valid Acc: 0.9148
# Using hidden size of:  320 num layers:  1
# Epoch [17/25], Train Loss: 0.3019, Train Acc: 0.9507, Valid Loss: 0.3640, Valid Acc: 0.9172
# Using hidden size of:  320 num layers:  1
# Epoch [18/25], Train Loss: 0.2870, Train Acc: 0.9538, Valid Loss: 0.3521, Valid Acc: 0.9197
# Using hidden size of:  320 num layers:  1
# Epoch [19/25], Train Loss: 0.2747, Train Acc: 0.9567, Valid Loss: 0.3425, Valid Acc: 0.9208
# Using hidden size of:  320 num layers:  1
# Epoch [20/25], Train Loss: 0.2611, Train Acc: 0.9593, Valid Loss: 0.3314, Valid Acc: 0.9237
# Using hidden size of:  320 num layers:  1
# Epoch [21/25], Train Loss: 0.2484, Train Acc: 0.9620, Valid Loss: 0.3226, Valid Acc: 0.9257
# Using hidden size of:  320 num layers:  1
# Epoch [22/25], Train Loss: 0.2365, Train Acc: 0.9647, Valid Loss: 0.3132, Valid Acc: 0.9273
# Using hidden size of:  320 num layers:  1
# Epoch [23/25], Train Loss: 0.2256, Train Acc: 0.9676, Valid Loss: 0.3061, Valid Acc: 0.9282
# Using hidden size of:  320 num layers:  1
# Epoch [24/25], Train Loss: 0.2152, Train Acc: 0.9700, Valid Loss: 0.2989, Valid Acc: 0.9283
# Using hidden size of:  320 num layers:  1
# Epoch [25/25], Train Loss: 0.2054, Train Acc: 0.9718, Valid Loss: 0.2928, Valid Acc: 0.9290
# Using hidden size of:  320 num layers:  2
# Epoch [1/25], Train Loss: 1.2790, Train Acc: 0.6311, Valid Loss: 0.9925, Valid Acc: 0.7508
# Using hidden size of:  320 num layers:  2
# Epoch [2/25], Train Loss: 0.9066, Train Acc: 0.7874, Valid Loss: 0.8433, Valid Acc: 0.7904
# Using hidden size of:  320 num layers:  2
# Epoch [3/25], Train Loss: 0.7793, Train Acc: 0.8317, Valid Loss: 0.7543, Valid Acc: 0.8283
# Using hidden size of:  320 num layers:  2
# Epoch [4/25], Train Loss: 0.6994, Train Acc: 0.8559, Valid Loss: 0.7425, Valid Acc: 0.8095
# Using hidden size of:  320 num layers:  2
# Epoch [5/25], Train Loss: 0.6411, Train Acc: 0.8696, Valid Loss: 0.6509, Valid Acc: 0.8546
# Using hidden size of:  320 num layers:  2
# Epoch [6/25], Train Loss: 0.5915, Train Acc: 0.8818, Valid Loss: 0.6154, Valid Acc: 0.8578
# Using hidden size of:  320 num layers:  2
# Epoch [7/25], Train Loss: 0.5504, Train Acc: 0.8910, Valid Loss: 0.5757, Valid Acc: 0.8704
# Using hidden size of:  320 num layers:  2
# Epoch [8/25], Train Loss: 0.5155, Train Acc: 0.8987, Valid Loss: 0.6045, Valid Acc: 0.8505
# Using hidden size of:  320 num layers:  2
# Epoch [9/25], Train Loss: 0.4847, Train Acc: 0.9053, Valid Loss: 0.5612, Valid Acc: 0.8608
# Using hidden size of:  320 num layers:  2
# Epoch [10/25], Train Loss: 0.4578, Train Acc: 0.9104, Valid Loss: 0.5117, Valid Acc: 0.8799
# Using hidden size of:  320 num layers:  2
# Epoch [11/25], Train Loss: 0.4326, Train Acc: 0.9156, Valid Loss: 0.4987, Valid Acc: 0.8786
# Using hidden size of:  320 num layers:  2
# Epoch [12/25], Train Loss: 0.4114, Train Acc: 0.9197, Valid Loss: 0.4950, Valid Acc: 0.8763
# Using hidden size of:  320 num layers:  2
# Epoch [13/25], Train Loss: 0.3899, Train Acc: 0.9246, Valid Loss: 0.4777, Valid Acc: 0.8767
# Using hidden size of:  320 num layers:  2
# Epoch [14/25], Train Loss: 0.3700, Train Acc: 0.9291, Valid Loss: 0.4581, Valid Acc: 0.8826
# Using hidden size of:  320 num layers:  2
# Epoch [15/25], Train Loss: 0.3518, Train Acc: 0.9337, Valid Loss: 0.5495, Valid Acc: 0.8417
# Using hidden size of:  320 num layers:  2
# Epoch [16/25], Train Loss: 0.3391, Train Acc: 0.9355, Valid Loss: 0.4334, Valid Acc: 0.8872
# Using hidden size of:  320 num layers:  2
# Epoch [17/25], Train Loss: 0.3207, Train Acc: 0.9409, Valid Loss: 0.4242, Valid Acc: 0.8888
# Using hidden size of:  320 num layers:  2
# Epoch [18/25], Train Loss: 0.3057, Train Acc: 0.9439, Valid Loss: 0.4121, Valid Acc: 0.8924
# Using hidden size of:  320 num layers:  2
# Epoch [19/25], Train Loss: 0.2926, Train Acc: 0.9472, Valid Loss: 0.4126, Valid Acc: 0.8884
# Using hidden size of:  320 num layers:  2
# Epoch [20/25], Train Loss: 0.2792, Train Acc: 0.9505, Valid Loss: 0.4062, Valid Acc: 0.8898
# Using hidden size of:  320 num layers:  2
# Epoch [21/25], Train Loss: 0.2667, Train Acc: 0.9534, Valid Loss: 0.4049, Valid Acc: 0.8887
# Using hidden size of:  320 num layers:  2
# Epoch [22/25], Train Loss: 0.2550, Train Acc: 0.9567, Valid Loss: 0.4034, Valid Acc: 0.8873
# Using hidden size of:  320 num layers:  2
# Epoch [23/25], Train Loss: 0.2441, Train Acc: 0.9590, Valid Loss: 0.3838, Valid Acc: 0.8923
# Using hidden size of:  320 num layers:  2
# Epoch [24/25], Train Loss: 0.2339, Train Acc: 0.9615, Valid Loss: 0.3832, Valid Acc: 0.8922
# Using hidden size of:  320 num layers:  2
# Epoch [25/25], Train Loss: 0.2242, Train Acc: 0.9642, Valid Loss: 0.3802, Valid Acc: 0.8902
# Using hidden size of:  350 num layers:  1
# Epoch [1/25], Train Loss: 1.2786, Train Acc: 0.6325, Valid Loss: 0.9718, Valid Acc: 0.7648
# Using hidden size of:  350 num layers:  1
# Epoch [2/25], Train Loss: 0.8953, Train Acc: 0.7977, Valid Loss: 0.7974, Valid Acc: 0.8223
# Using hidden size of:  350 num layers:  1
# Epoch [3/25], Train Loss: 0.7638, Train Acc: 0.8412, Valid Loss: 0.7087, Valid Acc: 0.8508
# Using hidden size of:  350 num layers:  1
# Epoch [4/25], Train Loss: 0.6821, Train Acc: 0.8659, Valid Loss: 0.6402, Valid Acc: 0.8707
# Using hidden size of:  350 num layers:  1
# Epoch [5/25], Train Loss: 0.6215, Train Acc: 0.8812, Valid Loss: 0.6147, Valid Acc: 0.8715
# Using hidden size of:  350 num layers:  1
# Epoch [6/25], Train Loss: 0.5729, Train Acc: 0.8928, Valid Loss: 0.5659, Valid Acc: 0.8845
# Using hidden size of:  350 num layers:  1
# Epoch [7/25], Train Loss: 0.5334, Train Acc: 0.9003, Valid Loss: 0.5832, Valid Acc: 0.8718
# Using hidden size of:  350 num layers:  1
# Epoch [8/25], Train Loss: 0.4998, Train Acc: 0.9077, Valid Loss: 0.5303, Valid Acc: 0.8820
# Using hidden size of:  350 num layers:  1
# Epoch [9/25], Train Loss: 0.4689, Train Acc: 0.9136, Valid Loss: 0.4882, Valid Acc: 0.8938
# Using hidden size of:  350 num layers:  1
# Epoch [10/25], Train Loss: 0.4380, Train Acc: 0.9210, Valid Loss: 0.4686, Valid Acc: 0.8951
# Using hidden size of:  350 num layers:  1
# Epoch [11/25], Train Loss: 0.4119, Train Acc: 0.9266, Valid Loss: 0.4419, Valid Acc: 0.9047
# Using hidden size of:  350 num layers:  1
# Epoch [12/25], Train Loss: 0.3883, Train Acc: 0.9312, Valid Loss: 0.4295, Valid Acc: 0.9038
# Using hidden size of:  350 num layers:  1
# Epoch [13/25], Train Loss: 0.3666, Train Acc: 0.9367, Valid Loss: 0.4127, Valid Acc: 0.9067
# Using hidden size of:  350 num layers:  1
# Epoch [14/25], Train Loss: 0.3468, Train Acc: 0.9409, Valid Loss: 0.4012, Valid Acc: 0.9076
# Using hidden size of:  350 num layers:  1
# Epoch [15/25], Train Loss: 0.3285, Train Acc: 0.9448, Valid Loss: 0.3875, Valid Acc: 0.9105
# Using hidden size of:  350 num layers:  1
# Epoch [16/25], Train Loss: 0.3114, Train Acc: 0.9489, Valid Loss: 0.3732, Valid Acc: 0.9134
# Using hidden size of:  350 num layers:  1
# Epoch [17/25], Train Loss: 0.2954, Train Acc: 0.9521, Valid Loss: 0.3623, Valid Acc: 0.9149
# Using hidden size of:  350 num layers:  1
# Epoch [18/25], Train Loss: 0.2805, Train Acc: 0.9553, Valid Loss: 0.3528, Valid Acc: 0.9151
# Using hidden size of:  350 num layers:  1
# Epoch [19/25], Train Loss: 0.2666, Train Acc: 0.9588, Valid Loss: 0.3423, Valid Acc: 0.9188
# Using hidden size of:  350 num layers:  1
# Epoch [20/25], Train Loss: 0.2534, Train Acc: 0.9616, Valid Loss: 0.3348, Valid Acc: 0.9202
# Using hidden size of:  350 num layers:  1
# Epoch [21/25], Train Loss: 0.2412, Train Acc: 0.9646, Valid Loss: 0.3257, Valid Acc: 0.9219
# Using hidden size of:  350 num layers:  1
# Epoch [22/25], Train Loss: 0.2297, Train Acc: 0.9676, Valid Loss: 0.3205, Valid Acc: 0.9234
# Using hidden size of:  350 num layers:  1
# Epoch [23/25], Train Loss: 0.2187, Train Acc: 0.9701, Valid Loss: 0.3131, Valid Acc: 0.9234
# Using hidden size of:  350 num layers:  1
# Epoch [24/25], Train Loss: 0.2084, Train Acc: 0.9725, Valid Loss: 0.3066, Valid Acc: 0.9245
# Using hidden size of:  350 num layers:  1
# Epoch [25/25], Train Loss: 0.1987, Train Acc: 0.9750, Valid Loss: 0.3002, Valid Acc: 0.9258
# Using hidden size of:  350 num layers:  2
# Epoch [1/25], Train Loss: 1.2306, Train Acc: 0.6534, Valid Loss: 1.0455, Valid Acc: 0.7201
# Using hidden size of:  350 num layers:  2
# Epoch [2/25], Train Loss: 0.8681, Train Acc: 0.8027, Valid Loss: 0.9169, Valid Acc: 0.7850
# Using hidden size of:  350 num layers:  2
# Epoch [3/25], Train Loss: 0.7534, Train Acc: 0.8420, Valid Loss: 0.8686, Valid Acc: 0.7788
# Using hidden size of:  350 num layers:  2
# Epoch [4/25], Train Loss: 0.6761, Train Acc: 0.8643, Valid Loss: 0.7410, Valid Acc: 0.8253
# Using hidden size of:  350 num layers:  2
# Epoch [5/25], Train Loss: 0.6188, Train Acc: 0.8804, Valid Loss: 0.6687, Valid Acc: 0.8478
# Using hidden size of:  350 num layers:  2
# Epoch [6/25], Train Loss: 0.5729, Train Acc: 0.8918, Valid Loss: 0.6246, Valid Acc: 0.8585
# Using hidden size of:  350 num layers:  2
# Epoch [7/25], Train Loss: 0.5342, Train Acc: 0.8992, Valid Loss: 0.6191, Valid Acc: 0.8496
# Using hidden size of:  350 num layers:  2
# Epoch [8/25], Train Loss: 0.5004, Train Acc: 0.9064, Valid Loss: 0.5607, Valid Acc: 0.8682
# Using hidden size of:  350 num layers:  2
# Epoch [9/25], Train Loss: 0.4702, Train Acc: 0.9133, Valid Loss: 0.5286, Valid Acc: 0.8768
# Using hidden size of:  350 num layers:  2
# Epoch [10/25], Train Loss: 0.4438, Train Acc: 0.9185, Valid Loss: 0.5606, Valid Acc: 0.8587
# Using hidden size of:  350 num layers:  2
# Epoch [11/25], Train Loss: 0.4216, Train Acc: 0.9226, Valid Loss: 0.5067, Valid Acc: 0.8756
# Using hidden size of:  350 num layers:  2
# Epoch [12/25], Train Loss: 0.3969, Train Acc: 0.9279, Valid Loss: 0.4729, Valid Acc: 0.8841
# Using hidden size of:  350 num layers:  2
# Epoch [13/25], Train Loss: 0.3758, Train Acc: 0.9324, Valid Loss: 0.4724, Valid Acc: 0.8853
# Using hidden size of:  350 num layers:  2
# Epoch [14/25], Train Loss: 0.3566, Train Acc: 0.9359, Valid Loss: 0.4425, Valid Acc: 0.8912
# Using hidden size of:  350 num layers:  2
# Epoch [15/25], Train Loss: 0.3389, Train Acc: 0.9404, Valid Loss: 0.4251, Valid Acc: 0.8946
# Using hidden size of:  350 num layers:  2
# Epoch [16/25], Train Loss: 0.3228, Train Acc: 0.9439, Valid Loss: 0.4222, Valid Acc: 0.8933
# Using hidden size of:  350 num layers:  2
# Epoch [17/25], Train Loss: 0.3080, Train Acc: 0.9469, Valid Loss: 0.4017, Valid Acc: 0.8976
# Using hidden size of:  350 num layers:  2
# Epoch [18/25], Train Loss: 0.2935, Train Acc: 0.9500, Valid Loss: 0.3952, Valid Acc: 0.8992
# Using hidden size of:  350 num layers:  2
# Epoch [19/25], Train Loss: 0.2800, Train Acc: 0.9527, Valid Loss: 0.3969, Valid Acc: 0.8934
# Using hidden size of:  350 num layers:  2
# Epoch [20/25], Train Loss: 0.2675, Train Acc: 0.9552, Valid Loss: 0.3819, Valid Acc: 0.8988
# Using hidden size of:  350 num layers:  2
# Epoch [21/25], Train Loss: 0.2557, Train Acc: 0.9581, Valid Loss: 0.3729, Valid Acc: 0.8984
# Using hidden size of:  350 num layers:  2
# Epoch [22/25], Train Loss: 0.2445, Train Acc: 0.9606, Valid Loss: 0.3669, Valid Acc: 0.8987
# Using hidden size of:  350 num layers:  2
# Epoch [23/25], Train Loss: 0.2338, Train Acc: 0.9629, Valid Loss: 0.3441, Valid Acc: 0.9087
# Using hidden size of:  350 num layers:  2
# Epoch [24/25], Train Loss: 0.2237, Train Acc: 0.9651, Valid Loss: 0.3451, Valid Acc: 0.9060
# Using hidden size of:  350 num layers:  2
# Epoch [25/25], Train Loss: 0.2141, Train Acc: 0.9675, Valid Loss: 0.3334, Valid Acc: 0.9101
# Using hidden size of:  400 num layers:  1
# Epoch [1/25], Train Loss: 1.2672, Train Acc: 0.6374, Valid Loss: 0.9886, Valid Acc: 0.7483
# Using hidden size of:  400 num layers:  1
# Epoch [2/25], Train Loss: 0.8774, Train Acc: 0.8045, Valid Loss: 0.7967, Valid Acc: 0.8233
# Using hidden size of:  400 num layers:  1
# Epoch [3/25], Train Loss: 0.7474, Train Acc: 0.8471, Valid Loss: 0.6970, Valid Acc: 0.8527
# Using hidden size of:  400 num layers:  1
# Epoch [4/25], Train Loss: 0.6684, Train Acc: 0.8707, Valid Loss: 0.6640, Valid Acc: 0.8548
# Using hidden size of:  400 num layers:  1
# Epoch [5/25], Train Loss: 0.6141, Train Acc: 0.8834, Valid Loss: 0.5861, Valid Acc: 0.8817
# Using hidden size of:  400 num layers:  1
# Epoch [6/25], Train Loss: 0.5658, Train Acc: 0.8954, Valid Loss: 0.5480, Valid Acc: 0.8897
# Using hidden size of:  400 num layers:  1
# Epoch [7/25], Train Loss: 0.5256, Train Acc: 0.9041, Valid Loss: 0.5146, Valid Acc: 0.8968
# Using hidden size of:  400 num layers:  1
# Epoch [8/25], Train Loss: 0.4914, Train Acc: 0.9125, Valid Loss: 0.4871, Valid Acc: 0.8996
# Using hidden size of:  400 num layers:  1
# Epoch [9/25], Train Loss: 0.4601, Train Acc: 0.9195, Valid Loss: 0.4669, Valid Acc: 0.9030
# Using hidden size of:  400 num layers:  1
# Epoch [10/25], Train Loss: 0.4314, Train Acc: 0.9251, Valid Loss: 0.4413, Valid Acc: 0.9064
# Using hidden size of:  400 num layers:  1
# Epoch [11/25], Train Loss: 0.4055, Train Acc: 0.9306, Valid Loss: 0.4266, Valid Acc: 0.9095
# Using hidden size of:  400 num layers:  1
# Epoch [12/25], Train Loss: 0.3820, Train Acc: 0.9358, Valid Loss: 0.4088, Valid Acc: 0.9114
# Using hidden size of:  400 num layers:  1
# Epoch [13/25], Train Loss: 0.3606, Train Acc: 0.9409, Valid Loss: 0.3938, Valid Acc: 0.9135
# Using hidden size of:  400 num layers:  1
# Epoch [14/25], Train Loss: 0.3407, Train Acc: 0.9451, Valid Loss: 0.3806, Valid Acc: 0.9153
# Using hidden size of:  400 num layers:  1
# Epoch [15/25], Train Loss: 0.3223, Train Acc: 0.9486, Valid Loss: 0.3659, Valid Acc: 0.9183
# Using hidden size of:  400 num layers:  1
# Epoch [16/25], Train Loss: 0.3051, Train Acc: 0.9522, Valid Loss: 0.3560, Valid Acc: 0.9194
# Using hidden size of:  400 num layers:  1
# Epoch [17/25], Train Loss: 0.2890, Train Acc: 0.9550, Valid Loss: 0.3482, Valid Acc: 0.9188
# Using hidden size of:  400 num layers:  1
# Epoch [18/25], Train Loss: 0.2740, Train Acc: 0.9595, Valid Loss: 0.3368, Valid Acc: 0.9208
# Using hidden size of:  400 num layers:  1
# Epoch [19/25], Train Loss: 0.2602, Train Acc: 0.9621, Valid Loss: 0.3313, Valid Acc: 0.9185
# Using hidden size of:  400 num layers:  1
# Epoch [20/25], Train Loss: 0.2472, Train Acc: 0.9649, Valid Loss: 0.3222, Valid Acc: 0.9210
# Using hidden size of:  400 num layers:  1
# Epoch [21/25], Train Loss: 0.2347, Train Acc: 0.9678, Valid Loss: 0.3182, Valid Acc: 0.9204
# Using hidden size of:  400 num layers:  1
# Epoch [22/25], Train Loss: 0.2232, Train Acc: 0.9706, Valid Loss: 0.3106, Valid Acc: 0.9220
# Using hidden size of:  400 num layers:  1
# Epoch [23/25], Train Loss: 0.2125, Train Acc: 0.9726, Valid Loss: 0.3069, Valid Acc: 0.9217
# Using hidden size of:  400 num layers:  1
# Epoch [24/25], Train Loss: 0.2023, Train Acc: 0.9749, Valid Loss: 0.3011, Valid Acc: 0.9229
# Using hidden size of:  400 num layers:  1
# Epoch [25/25], Train Loss: 0.1926, Train Acc: 0.9772, Valid Loss: 0.2948, Valid Acc: 0.9243
# Using hidden size of:  400 num layers:  2
# Epoch [1/25], Train Loss: 1.2153, Train Acc: 0.6613, Valid Loss: 0.9685, Valid Acc: 0.7694
# Using hidden size of:  400 num layers:  2
# Epoch [2/25], Train Loss: 0.8447, Train Acc: 0.8153, Valid Loss: 0.8567, Valid Acc: 0.7993
# Using hidden size of:  400 num layers:  2
# Epoch [3/25], Train Loss: 0.7355, Train Acc: 0.8502, Valid Loss: 0.8287, Valid Acc: 0.7990
# Using hidden size of:  400 num layers:  2
# Epoch [4/25], Train Loss: 0.6611, Train Acc: 0.8707, Valid Loss: 0.7738, Valid Acc: 0.8129
# Using hidden size of:  400 num layers:  2
# Epoch [5/25], Train Loss: 0.6069, Train Acc: 0.8852, Valid Loss: 0.7004, Valid Acc: 0.8314
# Using hidden size of:  400 num layers:  2
# Epoch [6/25], Train Loss: 0.5606, Train Acc: 0.8963, Valid Loss: 0.6423, Valid Acc: 0.8508
# Using hidden size of:  400 num layers:  2
# Epoch [7/25], Train Loss: 0.5263, Train Acc: 0.9032, Valid Loss: 0.6044, Valid Acc: 0.8581
# Using hidden size of:  400 num layers:  2
# Epoch [8/25], Train Loss: 0.4910, Train Acc: 0.9109, Valid Loss: 0.5842, Valid Acc: 0.8594
# Using hidden size of:  400 num layers:  2
# Epoch [9/25], Train Loss: 0.4593, Train Acc: 0.9173, Valid Loss: 0.5663, Valid Acc: 0.8604
# Using hidden size of:  400 num layers:  2
# Epoch [10/25], Train Loss: 0.4317, Train Acc: 0.9226, Valid Loss: 0.5348, Valid Acc: 0.8708
# Using hidden size of:  400 num layers:  2
# Epoch [11/25], Train Loss: 0.4071, Train Acc: 0.9282, Valid Loss: 0.5121, Valid Acc: 0.8753
# Using hidden size of:  400 num layers:  2
# Epoch [12/25], Train Loss: 0.3856, Train Acc: 0.9325, Valid Loss: 0.5078, Valid Acc: 0.8752
# Using hidden size of:  400 num layers:  2
# Epoch [13/25], Train Loss: 0.3653, Train Acc: 0.9367, Valid Loss: 0.4968, Valid Acc: 0.8742
# Using hidden size of:  400 num layers:  2
# Epoch [14/25], Train Loss: 0.3461, Train Acc: 0.9405, Valid Loss: 0.4611, Valid Acc: 0.8851
# Using hidden size of:  400 num layers:  2
# Epoch [15/25], Train Loss: 0.3276, Train Acc: 0.9452, Valid Loss: 0.4651, Valid Acc: 0.8804
# Using hidden size of:  400 num layers:  2
# Epoch [16/25], Train Loss: 0.3109, Train Acc: 0.9484, Valid Loss: 0.4346, Valid Acc: 0.8898
# Using hidden size of:  400 num layers:  2
# Epoch [17/25], Train Loss: 0.2954, Train Acc: 0.9513, Valid Loss: 0.4262, Valid Acc: 0.8893
# Using hidden size of:  400 num layers:  2
# Epoch [18/25], Train Loss: 0.2810, Train Acc: 0.9545, Valid Loss: 0.4222, Valid Acc: 0.8884
# Using hidden size of:  400 num layers:  2
# Epoch [19/25], Train Loss: 0.2674, Train Acc: 0.9582, Valid Loss: 0.4245, Valid Acc: 0.8852
# Using hidden size of:  400 num layers:  2
# Epoch [20/25], Train Loss: 0.2555, Train Acc: 0.9608, Valid Loss: 0.4203, Valid Acc: 0.8827
# Using hidden size of:  400 num layers:  2
# Epoch [21/25], Train Loss: 0.2433, Train Acc: 0.9628, Valid Loss: 0.4089, Valid Acc: 0.8877
# Using hidden size of:  400 num layers:  2
# Epoch [22/25], Train Loss: 0.2317, Train Acc: 0.9658, Valid Loss: 0.3958, Valid Acc: 0.8913
# Using hidden size of:  400 num layers:  2
# Epoch [23/25], Train Loss: 0.2211, Train Acc: 0.9681, Valid Loss: 0.3924, Valid Acc: 0.8899
# Using hidden size of:  400 num layers:  2
# Epoch [24/25], Train Loss: 0.2112, Train Acc: 0.9707, Valid Loss: 0.3801, Valid Acc: 0.8948
# Using hidden size of:  400 num layers:  2
# Epoch [25/25], Train Loss: 0.2032, Train Acc: 0.9722, Valid Loss: 0.3687, Valid Acc: 0.8997
# Training time: 416.9100914041201 mins

# %%
best_model
# Out:
# RNNAudioModel(
#   (rnn): RNN(507, 320, batch_first=True)
#   (fc1): Linear(in_features=320, out_features=100, bias=True)
#   (bn1): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=100, out_features=64, bias=True)
#   (bn2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=64, out_features=10, bias=True)
#   (bn3): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
bestRNN = best_model
bestAudioEmbeddings = best_audio_embedding_per_model[best_model_name]
best_audio_embedding_list = audio_embedding_list[best_model_name]
best_audio_labels = audio_labels[best_model_name]

# %%
print(len(audio_labels))
print(bestAudioEmbeddings.shape)
print(len(best_audio_embedding_list))
# Out:
# 1
# torch.Size([64, 64])
# 750

# %%
bestRNN.eval()
predictedAll = []

with torch.no_grad():
    for data in test_loader_audios:
        inputs = data[0]  # Extract the input tensor from the tuple
        outputs, _ = bestRNN(inputs)
        predicted = torch.argmax(outputs, 1)
        predictedAll.append(predicted)

# Concatenate predictions from all samples
all_predictions = torch.cat(predictedAll, dim=0)

print(all_predictions.shape)  # Check the shape of all_predictions
# Out:
# torch.Size([10000])

# %% [raw]
# # final parameters:
#
# Audio model: bestRNN
# audio train data: train_loader_audio
#
# audio test data: test_loader_audio
#
# audio embeddings: bestAudioEmbeddings
#
# all audio embeddings = best_audio_embedding_list

# %%
# export the data to excel
finalPreds = pd.DataFrame(all_predictions, columns=["preds"])
finalPreds.to_csv("rnn_audio_preds.csv", index=False)

# %%
# creating a multi-modal model

# %%
class MultimodalModel(nn.Module):
    def __init__(self, image_model, audio_model, num_classes, n_fc):
        super(MultimodalModel, self).__init__()
        self.image_model = image_model
        self.audio_model = audio_model
        self.n_fc = n_fc
        if n_fc == 1:
            self.fc1 = nn.Linear(64+64, num_classes)  
        else:
            self.fc1 = nn.Linear(64+64, 64)  
            self.fc2 = nn.Linear(64, num_classes)  

    def forward(self, image_input, audio_input):
        _, image_out = self.image_model(image_input)
        _, audio_out = self.audio_model(audio_input)
        
        image_out = F.relu(image_out)
        audio_out = F.relu(audio_out)
        
        combined_out = torch.cat((image_out, audio_out), dim=1)
#         print("here")
#         print(combined_out.shape)
        if n_fc == 1:
            output1 = self.fc1(combined_out)
        else:
            output = self.fc1(combined_out)
            output1 = self.fc2(output)
        return output1


def validate_multimodal_model(multimodal_model, image_loader, audio_loader, criterion):
    total_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for image_data, audio_data in zip(image_loader, audio_loader):
            image_inputs, image_labels = image_data
            audio_inputs, audio_labels = audio_data
            image_inputs = image_inputs.view(-1, 1, 28, 28)

            outputs = multimodal_model(image_inputs, audio_inputs)
            loss = criterion(outputs, image_labels.long())
            total_loss += loss.item()

            _, predicted = torch.max(outputs, 1)
            total += image_labels.size(0)
            correct += (predicted == image_labels).sum().item()

    accuracy = 100 * correct / total
    return total_loss / len(image_loader), accuracy


def train_multimodal_model(multimodal_model, image_loader, audio_loader, criterion, optimizer, image_valid_loader, audio_valid_loader, epochs=10):
    for epoch in range(epochs):
        running_loss = 0.0
        for i, (image_data, audio_data) in enumerate(zip(image_loader, audio_loader)):
            image_inputs, image_labels = image_data
            audio_inputs, audio_labels = audio_data
            image_inputs = image_inputs.view(-1, 1, 28, 28)
            optimizer.zero_grad()

            # Forward pass
            outputs = multimodal_model(image_inputs, audio_inputs)
            loss = criterion(outputs, image_labels.long())

            # Backward pass and optimization
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

            # Print loss for each batch
            if i % 100 == 99:  # Print every 100 batches
                print(f'Epoch {epoch+1}, Batch {i+1}/{len(image_loader)}, Loss: {running_loss/100}')
                running_loss = 0.0

        # Print epoch loss
        epoch_loss = running_loss / len(image_loader)
        print(f'Epoch {epoch+1}/{epochs}, Training Loss: {epoch_loss}')

        # Validation
        if image_valid_loader is not None and audio_valid_loader is not None:
            val_loss, val_accuracy = validate_multimodal_model(multimodal_model, image_valid_loader, audio_valid_loader, criterion)
            print(f'Epoch {epoch+1}/{epochs}, Validation Loss: {val_loss}, Validation Accuracy: {val_accuracy}%')
    print('Training Finished!')
    return val_accuracy

def predict_multimodal_model(multimodal_model, image_loader, audio_loader):
    predictions = []
    with torch.no_grad():
        for (image_inputs), (audio_inputs) in zip(image_loader, audio_loader):
            
            image_inputs = image_inputs[0]
            image_inputs = image_inputs.view(-1, 1, 28, 28)
            audio_inputs = audio_inputs[0]
            outputs = multimodal_model(image_inputs, audio_inputs)
            _, predicted = torch.max(outputs, 1)
            predictions.extend(predicted.numpy())
    return predictions

# %% [raw]
# # final parameters:
#
# Audio model: bestRNN
# Image model: bestModel
#
# image train data: train_loader_images
# image test data: test_loader_images
#
# audio train data: train_loader_audio
# audio test data: test_loader_audio
#
# audio embeddings: bestAudioEmbeddings
# image embeddings: image_embedding_best_model
#
# all image embeddings = best_image_embedding_list
# all audio embeddings = best_audio_embedding_list

# %%
# Create the multi-modal model
number_of_fc = [1,2]
max_mm_accuracy = 0
for n_fc in number_of_fc:
    multimodal_model = MultimodalModel(bestModel, bestRNN, 10, n_fc)

    # Define loss function and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(multimodal_model.parameters())

    # Train the multi-modal model
    curr_accuracy = train_multimodal_model(multimodal_model, train_loader_images, train_loader_audios, criterion, optimizer, valid_loader_images, valid_loader_audios, 10)
    if curr_accuracy > max_mm_accuracy:
        max_mm_accuracy = curr_accuracy
        bestMMmodel = multimodal_model
# Out:
# Epoch 1, Batch 100/750, Loss: 0.25547060843673536
# Epoch 1, Batch 200/750, Loss: 0.03892065987223759
# Epoch 1, Batch 300/750, Loss: 0.048385718414210716
# Epoch 1, Batch 400/750, Loss: 0.04078288759221323
# Epoch 1, Batch 500/750, Loss: 0.03734425977803767
# Epoch 1, Batch 600/750, Loss: 0.031088384570903144
# Epoch 1, Batch 700/750, Loss: 0.042864038776024245
# Epoch 1/10, Training Loss: 0.0016892919070087373
# Epoch 1/10, Validation Loss: 0.05702277603887388, Validation Accuracy: 98.40833333333333%
# Epoch 2, Batch 100/750, Loss: 0.03250644525920507
# Epoch 2, Batch 200/750, Loss: 0.025113973572733813
# Epoch 2, Batch 300/750, Loss: 0.03449008148571011
# Epoch 2, Batch 400/750, Loss: 0.0339795692905318
# Epoch 2, Batch 500/750, Loss: 0.02543619567528367
# Epoch 2, Batch 600/750, Loss: 0.023966192237567158
# Epoch 2, Batch 700/750, Loss: 0.030473036175826564
# Epoch 2/10, Training Loss: 0.001469795442884788
# Epoch 2/10, Validation Loss: 0.04878223526302076, Validation Accuracy: 98.68333333333334%
# Epoch 3, Batch 100/750, Loss: 0.023506080684746848
# Epoch 3, Batch 200/750, Loss: 0.02401982225215761
# Epoch 3, Batch 300/750, Loss: 0.03165125934930984
# Epoch 3, Batch 400/750, Loss: 0.029849562285817227
# Epoch 3, Batch 500/750, Loss: 0.020032192726794164
# Epoch 3, Batch 600/750, Loss: 0.020376349418074823
# Epoch 3, Batch 700/750, Loss: 0.024539006418781355
# Epoch 3/10, Training Loss: 0.0011809984507660071
# Epoch 3/10, Validation Loss: 0.05223266761636973, Validation Accuracy: 98.66666666666667%
# Epoch 4, Batch 100/750, Loss: 0.02098082311480539
# Epoch 4, Batch 200/750, Loss: 0.01717411053366959
# Epoch 4, Batch 300/750, Loss: 0.025245594026782784
# Epoch 4, Batch 400/750, Loss: 0.02473079135437729
# Epoch 4, Batch 500/750, Loss: 0.017938506538339425
# Epoch 4, Batch 600/750, Loss: 0.016380303487239872
# Epoch 4, Batch 700/750, Loss: 0.02276775015605381
# Epoch 4/10, Training Loss: 0.0012065750695765018
# Epoch 4/10, Validation Loss: 0.049307716348034485, Validation Accuracy: 98.76666666666667%
# Epoch 5, Batch 100/750, Loss: 0.021794651062591583
# Epoch 5, Batch 200/750, Loss: 0.016165163016121368
# Epoch 5, Batch 300/750, Loss: 0.022841336840428994
# Epoch 5, Batch 400/750, Loss: 0.019330908293122773
# Epoch 5, Batch 500/750, Loss: 0.015478615442261798
# Epoch 5, Batch 600/750, Loss: 0.013304865102909388
# Epoch 5, Batch 700/750, Loss: 0.023728233369329246
# Epoch 5/10, Training Loss: 0.0007656369541461269
# Epoch 5/10, Validation Loss: 0.05002720624628289, Validation Accuracy: 98.8%
# Epoch 6, Batch 100/750, Loss: 0.017104913808798302
# Epoch 6, Batch 200/750, Loss: 0.012732442913111298
# Epoch 6, Batch 300/750, Loss: 0.018173944380796458
# Epoch 6, Batch 400/750, Loss: 0.021445323981461116
# Epoch 6, Batch 500/750, Loss: 0.017246665131679037
# Epoch 6, Batch 600/750, Loss: 0.013840105342533207
# Epoch 6, Batch 700/750, Loss: 0.01871615236872458
# Epoch 6/10, Training Loss: 0.0012991227464517578
# Epoch 6/10, Validation Loss: 0.05180276787448631, Validation Accuracy: 98.775%
# Epoch 7, Batch 100/750, Loss: 0.014880962724855635
# Epoch 7, Batch 200/750, Loss: 0.012911048769237822
# Epoch 7, Batch 300/750, Loss: 0.022420858942714405
# Epoch 7, Batch 400/750, Loss: 0.017737648064576207
# Epoch 7, Batch 500/750, Loss: 0.012267400602067937
# Epoch 7, Batch 600/750, Loss: 0.01134874084218609
# Epoch 7, Batch 700/750, Loss: 0.014576293488025839
# Epoch 7/10, Training Loss: 0.0006839492554233099
# Epoch 7/10, Validation Loss: 0.054308064392850436, Validation Accuracy: 98.73333333333333%
# Epoch 8, Batch 100/750, Loss: 0.015104937395226442
# Epoch 8, Batch 200/750, Loss: 0.013689527625283518
# Epoch 8, Batch 300/750, Loss: 0.017357746377492732
# Epoch 8, Batch 400/750, Loss: 0.017566582440485944
# Epoch 8, Batch 500/750, Loss: 0.010189019812405603
# Epoch 8, Batch 600/750, Loss: 0.012361855658873537
# Epoch 8, Batch 700/750, Loss: 0.01998908008874423
# Epoch 8/10, Training Loss: 0.001113538942746042
# Epoch 8/10, Validation Loss: 0.05037090453854344, Validation Accuracy: 98.83333333333333%
# Epoch 9, Batch 100/750, Loss: 0.009578261053065943
# Epoch 9, Batch 200/750, Loss: 0.01196334320862661
# Epoch 9, Batch 300/750, Loss: 0.007707848254322016
# Epoch 9, Batch 400/750, Loss: 0.014676233937007056
# Epoch 9, Batch 500/750, Loss: 0.01274633907552925
# Epoch 9, Batch 600/750, Loss: 0.00677691758986839
# Epoch 9, Batch 700/750, Loss: 0.014200152726430134
# Epoch 9/10, Training Loss: 0.00047558946474358287
# Epoch 9/10, Validation Loss: 0.05717971832570506, Validation Accuracy: 98.88333333333334%
# Epoch 10, Batch 100/750, Loss: 0.013717143473259056
# Epoch 10, Batch 200/750, Loss: 0.008406721981227747
# Epoch 10, Batch 300/750, Loss: 0.011364741581960516
# Epoch 10, Batch 400/750, Loss: 0.011693562609161745
# Epoch 10, Batch 500/750, Loss: 0.022648386514629238
# Epoch 10, Batch 600/750, Loss: 0.008326797766221717
# Epoch 10, Batch 700/750, Loss: 0.016057997547704872
# Epoch 10/10, Training Loss: 0.0009924050982808694
# Epoch 10/10, Validation Loss: 0.06420285988901633, Validation Accuracy: 98.59166666666667%
# Training Finished!
# Epoch 1, Batch 100/750, Loss: 0.2149330410762923
# Epoch 1, Batch 200/750, Loss: 0.008508662647363963
# Epoch 1, Batch 300/750, Loss: 0.013900583583072147
# Epoch 1, Batch 400/750, Loss: 0.012302898130001268
# Epoch 1, Batch 500/750, Loss: 0.009906864201366262
# Epoch 1, Batch 600/750, Loss: 0.015297824482186115
# Epoch 1, Batch 700/750, Loss: 0.021611654204716616
# Epoch 1/10, Training Loss: 0.0009698436200366511
# Epoch 1/10, Validation Loss: 0.06016690788972947, Validation Accuracy: 98.625%
# Epoch 2, Batch 100/750, Loss: 0.014028032990318025
# Epoch 2, Batch 200/750, Loss: 0.010507341928496316
# Epoch 2, Batch 300/750, Loss: 0.010393571726381197
# Epoch 2, Batch 400/750, Loss: 0.012079915356298442
# Epoch 2, Batch 500/750, Loss: 0.012379594430567522
# Epoch 2, Batch 600/750, Loss: 0.010889751515896932
# Epoch 2, Batch 700/750, Loss: 0.011052481895239908
# Epoch 2/10, Training Loss: 0.00035803657390351873
# Epoch 2/10, Validation Loss: 0.0881443410736075, Validation Accuracy: 98.325%
# Epoch 3, Batch 100/750, Loss: 0.01834655511593155
# Epoch 3, Batch 200/750, Loss: 0.011591930581180349
# Epoch 3, Batch 300/750, Loss: 0.01046243247210441
# Epoch 3, Batch 400/750, Loss: 0.008797633900185247
# Epoch 3, Batch 500/750, Loss: 0.007043961603721982
# Epoch 3, Batch 600/750, Loss: 0.008720290697556265
# Epoch 3, Batch 700/750, Loss: 0.013065218548854318
# Epoch 3/10, Training Loss: 0.0006003480198439017
# Epoch 3/10, Validation Loss: 0.049250687576954506, Validation Accuracy: 99.0%
# Epoch 4, Batch 100/750, Loss: 0.013943426513533268
# Epoch 4, Batch 200/750, Loss: 0.008921354650719877
# Epoch 4, Batch 300/750, Loss: 0.011476068921897422
# Epoch 4, Batch 400/750, Loss: 0.010270743658484207
# Epoch 4, Batch 500/750, Loss: 0.011648364882057649
# Epoch 4, Batch 600/750, Loss: 0.008251574044743392
# Epoch 4, Batch 700/750, Loss: 0.007309218574455371
# Epoch 4/10, Training Loss: 0.0007568109108882103
# Epoch 4/10, Validation Loss: 0.0644458081033008, Validation Accuracy: 98.7%
# Epoch 5, Batch 100/750, Loss: 0.011862896037309839
# Epoch 5, Batch 200/750, Loss: 0.007971325825419626
# Epoch 5, Batch 300/750, Loss: 0.013776367190694146
# Epoch 5, Batch 400/750, Loss: 0.007112909811876306
# Epoch 5, Batch 500/750, Loss: 0.005436066339257195
# Epoch 5, Batch 600/750, Loss: 0.010742750520305435
# Epoch 5, Batch 700/750, Loss: 0.01863700540582613
# Epoch 5/10, Training Loss: 0.00040053086384371755
# Epoch 5/10, Validation Loss: 0.07691268022411815, Validation Accuracy: 98.64166666666667%
# Epoch 6, Batch 100/750, Loss: 0.008291606582911299
# Epoch 6, Batch 200/750, Loss: 0.006927181239360039
# Epoch 6, Batch 300/750, Loss: 0.009293450291434056
# Epoch 6, Batch 400/750, Loss: 0.009056568151627288
# Epoch 6, Batch 500/750, Loss: 0.00952293372614804
# Epoch 6, Batch 600/750, Loss: 0.012209675036338012
# Epoch 6, Batch 700/750, Loss: 0.008277117070704207
# Epoch 6/10, Training Loss: 0.0008061742882976735
# Epoch 6/10, Validation Loss: 0.06105369149027149, Validation Accuracy: 98.95%
# Epoch 7, Batch 100/750, Loss: 0.011520772230201147
# Epoch 7, Batch 200/750, Loss: 0.010145653964186749
# Epoch 7, Batch 300/750, Loss: 0.0104302169252378
# Epoch 7, Batch 400/750, Loss: 0.007524387278051563
# Epoch 7, Batch 500/750, Loss: 0.011003286241211753
# Epoch 7, Batch 600/750, Loss: 0.011305066223794711
# Epoch 7, Batch 700/750, Loss: 0.012553756432489536
# Epoch 7/10, Training Loss: 0.00043748348979109626
# Epoch 7/10, Validation Loss: 0.07890930485509816, Validation Accuracy: 98.76666666666667%
# Epoch 8, Batch 100/750, Loss: 0.008233156443861845
# Epoch 8, Batch 200/750, Loss: 0.0078986531050964
# Epoch 8, Batch 300/750, Loss: 0.005718452385056025
# Epoch 8, Batch 400/750, Loss: 0.004939428264201524
# Epoch 8, Batch 500/750, Loss: 0.00503520809641941
# Epoch 8, Batch 600/750, Loss: 0.01169873302207634
# Epoch 8, Batch 700/750, Loss: 0.011460290109612288
# Epoch 8/10, Training Loss: 0.0008699334593305442
# Epoch 8/10, Validation Loss: 0.07196522014897042, Validation Accuracy: 98.8%
# Epoch 9, Batch 100/750, Loss: 0.0052638677560844374
# Epoch 9, Batch 200/750, Loss: 0.00914260239757823
# Epoch 9, Batch 300/750, Loss: 0.009960653923667451
# Epoch 9, Batch 400/750, Loss: 0.014232245930288627
# Epoch 9, Batch 500/750, Loss: 0.012335350562379973
# Epoch 9, Batch 600/750, Loss: 0.010754375011247248
# Epoch 9, Batch 700/750, Loss: 0.0106982936722153
# Epoch 9/10, Training Loss: 0.000770624968058352
# Epoch 9/10, Validation Loss: 0.05487207894867289, Validation Accuracy: 98.9%
# Epoch 10, Batch 100/750, Loss: 0.0065902200034406635
# Epoch 10, Batch 200/750, Loss: 0.005734945730912386
# Epoch 10, Batch 300/750, Loss: 0.01990046167315086
# Epoch 10, Batch 400/750, Loss: 0.006518539922906257
# Epoch 10, Batch 500/750, Loss: 0.0033163774162596835
# Epoch 10, Batch 600/750, Loss: 0.012098135287175182
# Epoch 10, Batch 700/750, Loss: 0.0071251223302397195
# Epoch 10/10, Training Loss: 0.0003065461270750044
# Epoch 10/10, Validation Loss: 0.07360113754557847, Validation Accuracy: 98.78333333333333%
# Training Finished!

# %%
# Make predictions using the multi-modal model
predictions = predict_multimodal_model(bestMMmodel, test_loader_images, test_loader_audios)

# %%
# export the data to excel
#finalPreds = pd.DataFrame(predictions, columns=["preds"])
finalPreds = pd.DataFrame({'row_id': range(len(predictions)), 'preds': predictions})

finalPreds.to_csv("multimodal_preds.csv", index=False)

# %%
#(t-SNE) t-Distributed Stochastic Neighbor Embedding 

# very very slow!

# %%
# RUn the below to use pre - saved embeddings:

# %%
# Convert the list of NumPy arrays to a single NumPy array
image_embedding_numpy_list = [tensor.detach().numpy() for tensor in best_image_embedding_list]
audio_embedding_numpy_list = [tensor.detach().numpy() for tensor in best_audio_embedding_list]

image_embeddings_np = np.concatenate(image_embedding_numpy_list, axis=0)
audio_embeddings_np = np.concatenate(audio_embedding_numpy_list, axis=0)

# %%
# Reshape to the desired shape
image_embeddings_np = image_embeddings_np.reshape(-1, 64)
audio_embeddings_np = audio_embeddings_np.reshape(-1, 64)

# %%
print(image_embeddings_np.shape)
print(audio_embeddings_np.shape)
# Out:
# (48000, 64)
# (48000, 64)

# %%
# save embeddings as numpy files

np.save('image_embedding.npy', image_embeddings_np)
np.save('audio_embedding.npy', audio_embeddings_np)

# %%
# image_embeddings_np = np.load('image_embedding.npy')
# audio_embeddings_np = np.load('audio_embedding.npy')

# %%
print(image_embeddings_np.shape)
print(audio_embeddings_np.shape)
# Out:
# (48000, 64)
# (48000, 64)

# %%
# Load embeddings from npy files
image_embedding = image_embeddings_np

# Apply PCA to reduce dimensionality to 2 dimensions
pca = PCA(n_components=2)
image_embedding_pca = pca.fit_transform(image_embedding)

plt.scatter(image_embedding_pca[:, 0], image_embedding_pca[:, 1], s=10)
plt.title('PCA-transformed Image Embeddings')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()

# %%
pca = PCA(n_components=2, svd_solver='randomized') 

audio_embedding = audio_embeddings_np
audio_embedding_pca = pca.fit_transform(audio_embedding)



plt.scatter(audio_embedding_pca[:, 0], audio_embedding_pca[:, 1], s=10)
plt.title('PCA-transformed Audio Embeddings')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()

# %%
class KMeans:
    def __init__(self, k, max_iter=100):
        self.k = k
        self.max_iter = max_iter

    def _init_centroids(self):
        return list(self.X[np.random.choice(self.X.shape[0], self.k, replace=False)])

    def _d(self, x, y):  # Euclidean distance
        return np.linalg.norm(x - y)

    def _cluster_assgnmnt(self):
        cluster_assignments = [[] for centroid in self.centroids]

        for i in range(self.X.shape[0]):
            centroid = np.argmin([self._d(self.X[i, :], centroid) for centroid in self.centroids])
            cluster_assignments[centroid].append(i)
        return cluster_assignments

    def _update_centroids(self, cluster_assignments):
        for i in range(len(self.centroids)):
            self.centroids[i] = np.mean(self.X[cluster_assignments[i]], axis=0)
        return self.centroids

    def fit(self, X):
        self.X = X

        self.centroids = self._init_centroids()
        cluster_assignments = self._cluster_assgnmnt()
        #self._plot(cluster_assignments)

        for i in range(self.max_iter):
            # assign clusters
            cluster_assignments = self._cluster_assgnmnt()

            # update centroids
            self.centroids = self._update_centroids(cluster_assignments)

            #if i % 5 == 4:
            #self._plot(cluster_assignments)
        self._plot(cluster_assignments)

    def _plot(self, cluster_assignments):
        idx_to_c = [None] * self.X.shape[0]
        for c, idxs in enumerate(cluster_assignments):
            for i in idxs:
                idx_to_c[i] = c

        plt.figure()
        plt.scatter(self.X[:, 0], self.X[:, 1], c=idx_to_c)
        plt.show()

# %%
kmeans = KMeans(k=10, max_iter=100)
kmeans.fit(image_embedding_pca)

# %%
kmeans = KMeans(k=10, max_iter=100)
kmeans.fit(audio_embedding_pca)

# %%
len(best_audio_labels)
# best_image_labels
# Out:
# 750

# %%
flattened_audio_labels = []
for tensor in best_audio_labels:
    flattened_audio_labels.extend(tensor.tolist())

# Verify the length of the flattened list (should be 48000)
print(len(flattened_audio_labels))
# Out:
# 48000

# %%
flattened_image_labels = []
for tensor in best_image_labels:
    flattened_image_labels.extend(tensor.tolist())

# Verify the length of the flattened list (should be 48000)
print(len(flattened_image_labels))
# Out:
# 48000

# %%
audio_embedding_pca
# Out:
# array([[-3.4515429 ,  1.4517148 ],
#        [ 3.920538  ,  3.4606607 ],
#        [-3.0009005 , -0.7618581 ],
#        ...,
#        [-2.0643466 ,  3.1700706 ],
#        [ 0.13872866,  2.6149328 ],
#        [-1.2017726 , -0.899247  ]], dtype=float32)

# %%
# Create a dictionary to map indices to labels
label_dict = {idx: label for idx, label in enumerate(flattened_audio_labels)}

# Plot all points with corresponding labels
plt.figure(figsize=(10, 8))
for i in range(10):  
    indices = [idx for idx, label in enumerate(flattened_audio_labels) if label == i]
    x = audio_embedding_pca[indices, 0]
    y = audio_embedding_pca[indices, 1]
    plt.scatter(x, y, label=f'Label {i}', alpha=0.5)

plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA Output with Color Legend')
plt.legend()
plt.grid(True)

# Set the limits of the x and y axes to increase resolution
# plt.xlim(x.min() - 0.1, x.max() + 0.1)
# plt.ylim(y.min() - 0.1, y.max() + 0.1)

plt.show()

# %%
# Create a dictionary to map indices to labels
label_dict = {idx: label for idx, label in enumerate(flattened_image_labels)}

# Plot all points with corresponding labels
plt.figure(figsize=(10, 8))
for i in range(10):  
    indices = [idx for idx, label in enumerate(flattened_image_labels) if label == i]
    x = image_embedding_pca[indices, 0]
    y = image_embedding_pca[indices, 1]
    plt.scatter(x, y, label=f'Label {i}', alpha=0.3)

plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA Output with Color Legend')
plt.legend()
plt.grid(True)
plt.show()

# %%
# EOF
